# %%
import numpy as np
import pandas as pd
import string
import re
import os
from transformers import AutoModel
from transformers import AutoTokenizer

# %%
# !pip install -U accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.29.1-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.3/297.3 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 23.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 36.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 23.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 6.1 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.0 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.0 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.29.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
# !pip install -U transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting transformers
#   Downloading transformers-4.39.3-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed transformers-4.39.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
suffix = 'drive/MyDrive/medical_dataset_analysis/'

beth_file_directory = 'concept_assertion_relation_training_data/beth/txt/'
beth_concept_directory = 'concept_assertion_relation_training_data/beth/ast/'

partner_file_directory = 'concept_assertion_relation_training_data/partners/txt/'
partner_concept_directory = 'concept_assertion_relation_training_data/partners/ast/'

test_directory = 'test_data/'
test_directory_concepts = 'reference_standard_for_test_data/ast/'

# %%
def getNotes(file_directory):
    text_dict = {}
    file_list = os.listdir(suffix+file_directory)
    for f in file_list:
        if f[-3:] != 'xml' and f[-3:] != 'txt' and f[-3:] != 'ast':
            file_list.remove(f)
    if '.DS_Store' in file_list:
        file_list.remove('.DS_Store')
    for file_name in file_list:
        with open(suffix+file_directory + file_name,'r') as file:
            data = file.read()
            text_dict[file_name[:-4]] = data
        file.close()
    return text_dict

# %%
beth_notes = getNotes(beth_file_directory)
beth_concepts = getNotes(beth_concept_directory)
partners_notes = getNotes(partner_file_directory)
partners_concepts = getNotes(partner_concept_directory)

# %%
all_notes = beth_notes.copy()
all_notes.update(partners_notes)

all_concepts = beth_concepts.copy()
all_concepts.update(partners_concepts)

test_notes = getNotes(test_directory)
test_concepts = getNotes(test_directory_concepts)

all_notes.update(test_notes)
all_concepts.update(test_concepts)

# %%
all_notes['record-21']
# Out:
# "01909607\nAdmission Date :\n2010-06-28\nDischarge Date :\n2010-07-01\nDate of Birth :\n1990-02-01\nSex :\nF\nService :\nORTHOPEDIC\nHISTORY OF THE PRESENT ILLNESS :\nThis is a 20-year-old female with no significant past medical history , who was the unrestrained passenger in a high speed rollover motor vehicle accident on 2010-06-27 .\nBy report , the patient was ejected from the vehicle on impact and found curled in the fetal position at the rear of the vehicle at the scene .\nThe vehicle was noted to be extensively damaged .\nBy report , the patient was noted to be awake , but confused at the scene of the accident with no memory of the incident .\nShe was immobilized in the C-spine collar at the scene of the accident and subsequently transported by EMS to the New England Sinai Hospital & Rehab Center Emergency Department for further management .\nPHYSICAL EXAMINATION :\nExamination on presentation to the emergency room revealed the following :\nTemperature 35.4 Celsius , blood pressure 116/63 , pulse 105 , respiratory rate 18 , oxygen saturation 98% on room air .\nThe patient was alert and oriented times three in no apparent distress .\nBoston Coma Scale of 15 .\nTympanic membranes were noted to be clear .\nPupils were equal , round , reactive to light at approximately 4 mm .\nThe patient 's trachea was noted to be midline .\nThe patient 's lung examination revealed the lungs to be clear to auscultation bilaterally , no crepitus , and a left clavicular deformity was grossly apparent on examination .\nCARDIAC :\nCardiac examination demonstrated regular rate and rhythm , no murmurs , rubs , or gallops .\nABDOMEN :\nSoft , nontender , nondistended .\nRECTAL :\nExamination was guaiac negative with good rectal tone .\nThe patient 's pelvis was stable to AP and lateral compression .\nA 5 cm laceration was noted over the patient 's occiput on further inspection with no exposed underlying bone .\nRight upper extremity examination demonstrated intact motor , sensory , and vascular function .\nLeft upper extremity examination demonstrated no gross deformities , tenderness to palpation in the mid forearm , intact motor function in the median , radial , and ulnar nerve distributions , intact sensation to light touch in the median and radial nerve distributions , decreased sensation in the ulnar-nerve distribution , warm and well perfused limb with 2+ radial pulses .\nRight lower extremity examination demonstrated mild swelling and ecchymosis of the right posterior thigh and approximately a 3 cm laceration in the lower leg , expressive of moderate amounts of standard sterile\nfashion .\nNo gross deformities .\nMotor , sensory , and vascular examinations were intact in all distributions .\nLeft lower extremity examination demonstrated no gross deformities and intact motor , sensory , and vascular examinations in all distributions .\nRadiographic studies demonstrated an inferior displaced left midclavicular fracture , no evidence of\npneumothorax .\nTrauma series demonstrated no evidence of a pelvic fracture .\nHead CT demonstrated no evidence of intracranial bleeding .\nTrauma CT demonstrated mild pulmonary contusions , but no pelvic fracture .\nCervical spine imaging demonstrated no evidence of cervical spine injury .\nRight tibial-fibular film series demonstrated no evidence of fracture displacement .\nLeft humerus film series demonstrated no evidence of fracture or displacement .\nRight foot and femur series demonstrated no evidence of fracture displacement .\nLeft forearm and wrist series demonstrated transverse mid shaft radial fracture with ulnar displacement .\nDiagnosis peritoneum lavage times two was negative for any signs of intra-abdominal bleeding .\nLABORATORY DATA :\nStudies on admission revealed the following :\nWhite blood cell 12.9 , hemoglobin 11.5 , hematocrit 32.8 , platelet count 197,000 , sodium 141 , potassium 3.6 , chloride 110 , bicarbonate 21 , BUN 20 , creatinine 0.7 , glucose 189 , PT 13.3 , INR 1.2 , PTT 30.0 ...

# %%
all_concepts['record-21']
# Out:
# 'c="left transverse mid shaft radial fracture" 90:1 90:6||t="problem"||a="present"\nc="ulnar displacement" 90:8 90:9||t="problem"||a="present"\nc="erythema" 79:22 79:22||t="problem"||a="absent"\nc="apparent distress" 21:10 21:11||t="problem"||a="absent"\nc="a 5 cm laceration" 34:0 34:3||t="problem"||a="present"\nc="exposed underlying bone" 34:16 34:18||t="problem"||a="absent"\nc="erythema" 72:3 72:3||t="problem"||a="absent"\nc="decreased sensation in the ulnar-nerve distribution" 36:44 36:49||t="problem"||a="present"\nc="gross deformities" 36:6 36:7||t="problem"||a="absent"\nc="tenderness" 36:9 36:9||t="problem"||a="present"\nc="right thigh hematoma" 61:29 61:31||t="problem"||a="present"\nc="major arterial or venous injury" 63:25 63:29||t="problem"||a="absent"\nc="the patient \'s right thigh hematoma" 63:1 63:6||t="problem"||a="present"\nc="rubs" 28:11 28:11||t="problem"||a="absent"\nc="mild swelling" 37:5 37:6||t="problem"||a="present"\nc="ecchymosis of the right posterior thigh" 37:8 37:13||t="problem"||a="present"\nc="a 3 cm laceration in the lower leg" 37:16 37:23||t="problem"||a="present"\nc="purulence" 79:24 79:24||t="problem"||a="absent"\nc="the patient \'s right anterior tibial wound" 79:0 79:6||t="problem"||a="present"\nc="crepitus" 26:16 26:16||t="problem"||a="absent"\nc="confused" 16:12 16:12||t="problem"||a="present"\nc="intracranial bleeding" 45:6 45:7||t="problem"||a="absent"\nc="pain" 101:2 101:2||t="problem"||a="hypothetical"\nc="right leg laceration" 61:34 61:36||t="problem"||a="present"\nc="injuries" 61:13 61:13||t="problem"||a="present"\nc="a posterior scalp laceration" 61:16 61:19||t="problem"||a="present"\nc="left fractured clavicle" 61:21 61:23||t="problem"||a="present"\nc="left fractured radius" 61:25 61:27||t="problem"||a="present"\nc="gross deformities" 41:6 41:7||t="problem"||a="absent"\nc="mild swelling" 76:0 76:1||t="problem"||a="present"\nc="a left clavicular deformity" 26:19 26:22||t="problem"||a="present"\nc="gallops" 28:14 28:14||t="problem"||a="absent"\nc="murmurs" 28:9 28:9||t="problem"||a="absent"\nc="left midclavicular fracture" 91:1 91:3||t="problem"||a="present"\nc="saturation" 74:19 74:19||t="problem"||a="absent"\nc="nontender" 30:2 30:2||t="problem"||a="absent"\nc="nondistended" 30:4 30:4||t="problem"||a="absent"\nc="a pelvic fracture" 44:6 44:8||t="problem"||a="absent"\nc="the scalp and right lower leg lacerations" 68:3 68:9||t="problem"||a="present"\nc="the left forearm and right lower leg wound" 99:0 99:7||t="problem"||a="present"\nc="gross deformities" 39:1 39:2||t="problem"||a="absent"\nc="an inferior displaced left midclavicular fracture" 42:3 42:8||t="problem"||a="present"\nc="pneumothorax" 43:0 43:0||t="problem"||a="absent"\nc="cervical spine injury" 47:7 47:9||t="problem"||a="absent"\nc="scalp laceration" 100:0 100:1||t="problem"||a="present"\nc="mild tenderness" 73:18 73:19||t="problem"||a="present"\nc="a minor stepoff" 73:14 73:16||t="problem"||a="present"\nc="pain" 95:9 95:9||t="problem"||a="hypothetical"\nc="right anterior tibial laceration" 93:1 93:4||t="problem"||a="present"\nc="occipital scalp laceration" 92:1 92:3||t="problem"||a="present"\nc="fracture displacement" 50:9 50:10||t="problem"||a="absent"\nc="pelvic fracture" 46:9 46:10||t="problem"||a="absent"\nc="mild pulmonary contusions" 46:3 46:5||t="problem"||a="present"\nc="transverse mid shaft radial fracture" 51:6 51:10||t="problem"||a="present"\nc="ulnar displacement" 51:12 51:13||t="problem"||a="present"\nc="purulence" 72:5 72:5||t="problem"||a="absent"\nc="intra-abdominal bleeding" 52:11 52:12||t="problem"||a="absent"\nc="continued ecchymosis" 73:7 73:8||t="problem"||a="present"\nc="fracture displacement" 48:8 48:9||t="problem"||a="absent"\nc="displacement" 49:10 49:10||t="problem"||a="absent"\nc="fracture" 49:8 49:8||t="problem"||a="absent"\nc="the patient \'s left clavicular fracture" 69:5 69:10||t="problem"||a="present"\nc="the patient \'s head wound laceration" 71:0 71:5||t="problem"||a="present"\n'

# %%
def get_tags(record):
  note = all_notes[record].split('\n')
  number_of_lines = len(note)

  all_note = []
  all_tag = []
  note_lines = [n.split() for n in note]
  tag_list = [['O' for j in i] for i in note_lines]

  concept_lines = all_concepts[record].split('\n')
  for i in concept_lines:
    if len(i) > 0:

      # print(i)
      c = re.findall(r'c=\".+"',i)
      stuff = re.findall('[0-9]{1,3}:[0-9]{1,3}\s[0-9]{1,3}:[0-9]{1,3}\|\|',i)[0]

      line = re.findall(r'[0-9]{1,3}:',stuff)
      line1 = int(line[0][:-1])
      line2 = int(line[1][:-1])

      indexes = re.findall(r':[0-9]{1,3}',stuff)
      ind1 = int(indexes[0][1:])
      ind2 = int(indexes[1][1:])

      t = re.findall(r'a=\"[a-z_]+\"',i)
      tag = t[0][3:-1]

      for line in range(line1,line2+1):
        for index in range(ind1,ind2+1):
            tag_list[line-1][index] = tag

  for t in tag_list:
    for ti in t:
      all_tag.append(ti)

  for n in note_lines:
    for ni in n:
      all_note.append(ni)
  return all_note, all_tag

records_dict = {}
for record in all_notes.keys():
  note,tag = get_tags(record)
  the_dict = {'words':note,'tags':tag}
  records_dict[record] = the_dict
# Out:
# Streaming output truncated to the last 5000 lines.
# c="aberrant left coronary artery" 108:1 108:4||t="problem"||a="present"
# ['a="present"']
# c="an anomalous left coronary artery arising from the pulmonary artery ( lcapa )" 52:9 52:21||t="problem"||a="possible"
# ['a="possible"']
# c="very rare spells" 47:7 47:9||t="problem"||a="present"
# ['a="present"']
# c="apnea of prematurity" 46:5 46:7||t="problem"||a="present"
# ['a="present"']
# c="a murmur" 32:5 32:6||t="problem"||a="absent"
# ['a="absent"']
# c="physiologic jaundice" 105:1 105:2||t="problem"||a="present"
# ['a="present"']
# c="sepsis" 104:1 104:1||t="problem"||a="absent"
# ['a="absent"']
# c="petechiae" 27:4 27:4||t="problem"||a="absent"
# ['a="absent"']
# c="bony abnormalities" 27:1 27:2||t="problem"||a="absent"
# ['a="absent"']
# c="anemia of prematurity" 107:1 107:3||t="problem"||a="present"
# ['a="present"']
# c="a non dysmorphic infant" 26:6 26:9||t="problem"||a="absent"
# ['a="absent"']
# c="multiple bruises" 26:16 26:17||t="problem"||a="present"
# ['a="present"']
# c="apnea of prematurity" 106:1 106:3||t="problem"||a="present"
# ['a="present"']
# c="breech presentation" 100:2 100:3||t="problem"||a="present"
# ['a="present"']
# c="breech presentation" 103:1 103:2||t="problem"||a="present"
# ['a="present"']
# c="prematurity" 102:1 102:1||t="problem"||a="present"
# ['a="present"']
# c="the breech position" 20:3 20:5||t="problem"||a="present"
# ['a="present"']
# c="known allergies" 12:5 12:6||t="problem"||a="absent"
# ['a="absent"']
# c="abomenal and and ascociated nausea" 19:14 19:18||t="problem"||a="present"
# ['a="present"']
# c="flatus" 21:1 21:1||t="problem"||a="absent"
# ['a="absent"']
# c="ischemia" 44:3 44:3||t="problem"||a="present"
# ['a="present"']
# c="infectious etiology" 45:0 45:1||t="problem"||a="possible"
# ['a="possible"']
# c="stricture" 43:10 43:10||t="problem"||a="possible"
# ['a="possible"']
# c="complications" 19:8 19:8||t="problem"||a="absent"
# ['a="absent"']
# c="internal hernia" 43:5 43:6||t="problem"||a="possible"
# ['a="possible"']
# c="hyperlipidemia" 26:0 26:0||t="problem"||a="present"
# ['a="present"']
# c="wound" 69:6 69:6||t="problem"||a="present"
# ['a="present"']
# c="ovarian cyst" 28:0 28:1||t="problem"||a="present"
# ['a="present"']
# c="obesity" 23:0 23:0||t="problem"||a="present"
# ['a="present"']
# c="ischemic small bowel" 48:12 48:14||t="problem"||a="present"
# ['a="present"']
# c="hypertension" 24:0 24:0||t="problem"||a="present"
# ['a="present"']
# c="gerd" 25:0 25:0||t="problem"||a="present"
# ['a="present"']
# c="peritomeal" 36:9 36:9||t="problem"||a="absent"
# ['a="absent"']
# c="small bowel obstruction" 48:8 48:10||t="problem"||a="present"
# ['a="present"']
# c="wound infection" 67:5 67:6||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="sudden fever" 67:10 67:11||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="increased pain" 67:13 67:14||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="nausea" 67:16 67:16||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="vomiting" 67:18 67:18||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="purulent discharge" 67:20 67:21||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="any complications" 52:17 52:18||t="problem"||a="absent"
# ['a="absent"']
# c="edema" 38:2 38:2||t="problem"||a="absent"
# ['a="absent"']
# c="afebrile" 52:3 52:3||t="problem"||a="absent"
# ['a="absent"']
# c="diffuse tenderness" 36:5 36:6||t="problem"||a="present"
# ['a="present"']
# c="non-distended" 36:3 36:3||t="problem"||a="absent"
# ['a="absent"']
# c="lymphanopathy" 33:1 33:1||t="problem"||a="absent"
# ['a="absent"']
# c="afebrile" 30:0 30:0||t="problem"||a="absent"
# ['a="absent"']
# c="closed loop obstruction" 42:8 42:10||t="problem"||a="present"
# ['a="present"']
# c="this small bowel obstruction" 42:0 42:3||t="problem"||a="present"
# ['a="present"']
# c="small bowel obstruction" 61:0 61:2||t="problem"||a="present"
# ['a="present"']
# c="nausea" 15:3 15:3||t="problem"||a="present"
# ['a="present"']
# c="abdomenal pain" 15:0 15:1||t="problem"||a="present"
# ['a="present"']
# c="slightly dilated small bowel" 40:9 40:12||t="problem"||a="present"
# ['a="present"']
# c="anicterus" 32:2 32:2||t="problem"||a="absent"
# ['a="absent"']
# c="bowel wall thickening" 40:17 40:19||t="problem"||a="possible"
# ['a="possible"']
# c="pain" 20:0 20:0||t="problem"||a="present"
# ['a="present"']
# c="ischemic small bowel" 62:0 62:2||t="problem"||a="present"
# ['a="present"']
# c="fecalization" 40:14 40:14||t="problem"||a="present"
# ['a="present"']
# c="an abnormal loop" 40:5 40:7||t="problem"||a="present"
# ['a="present"']
# c="epigastric discomfort" 21:1 21:2||t="problem"||a="present"
# ['a="present"']
# c="any further black stools" 117:3 117:6||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="bleeding" 117:8 117:8||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="gurgling gas-like pain" 21:4 21:6||t="problem"||a="present"
# ['a="present"']
# c="black tarry stools" 80:10 80:12||t="problem"||a="present"
# ['a="present"']
# c="lightheadedness" 22:1 22:1||t="problem"||a="conditional"
# ['a="conditional"']
# c="chills" 25:4 25:4||t="problem"||a="absent"
# ['a="absent"']
# c="gi bleed" 85:7 85:8||t="problem"||a="possible"
# ['a="possible"']
# c="hypercholestrolemia" 110:0 110:0||t="problem"||a="present"
# ['a="present"']
# c="htn" 19:5 19:5||t="problem"||a="present"
# ['a="present"']
# c="hyperchol" 19:7 19:7||t="problem"||a="present"
# ['a="present"']
# c="black tarry stools" 19:15 19:17||t="problem"||a="present"
# ['a="present"']
# c="peptic ulcer disease" 107:0 107:2||t="problem"||a="present"
# ['a="present"']
# c="gastritis" 108:0 108:0||t="problem"||a="present"
# ['a="present"']
# c="dark" 20:19 20:19||t="problem"||a="present"
# ['a="present"']
# c="tarry" 20:21 20:21||t="problem"||a="present"
# ['a="present"']
# c="hypertension" 109:0 109:0||t="problem"||a="present"
# ['a="present"']
# c="a. fib" 35:2 35:3||t="problem"||a="present"
# ['a="present"']
# c="hyperchol" 35:0 35:0||t="problem"||a="present"
# ['a="present"']
# c="htn" 34:0 34:0||t="problem"||a="present"
# ['a="present"']
# c="lightheadedness" 32:2 32:2||t="problem"||a="absent"
# ['a="absent"']
# c="lung ca" 40:5 40:6||t="problem"||a="associated_with_someone_else"
# ['a="associated_with_someone_else"']
# c="hemrroiids" 60:3 60:3||t="problem"||a="absent"
# ['a="absent"']
# c="n/v/d" 24:3 24:3||t="problem"||a="absent"
# ['a="absent"']
# c="mild epigastric tenderness" 57:6 57:8||t="problem"||a="present"
# ['a="present"']
# c="c/c/e bilaterally" 59:1 59:2||t="problem"||a="absent"
# ['a="absent"']
# c="brbpr" 24:1 24:1||t="problem"||a="absent"
# ['a="absent"']
# c="recent fevers" 25:1 25:2||t="problem"||a="absent"
# ['a="absent"']
# c="m/r/g" 56:6 56:6||t="problem"||a="absent"
# ['a="absent"']
# c="any other concerning symptoms" 117:12 117:15||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="lightheadedness" 117:10 117:10||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="loose stools" 20:7 20:8||t="problem"||a="present"
# ['a="present"']
# c="orthostatic" 28:3 28:3||t="problem"||a="present"
# ['a="present"']
# c="a non bleeding ulcer" 82:11 82:14||t="problem"||a="present"
# ['a="present"']
# c="gastritis" 82:16 82:16||t="problem"||a="present"
# ['a="present"']
# c="jvd" 52:5 52:5||t="problem"||a="absent"
# ['a="absent"']
# c="r/r/w" 54:4 54:4||t="problem"||a="absent"
# ['a="absent"']
# c="obese" 57:2 57:2||t="problem"||a="present"
# ['a="present"']
# c="st-t abnormalities" 65:1 65:2||t="problem"||a="absent"
# ['a="absent"']
# c="nad" 49:5 49:5||t="problem"||a="absent"
# ['a="absent"']
# c="sinus tach" 64:2 64:3||t="problem"||a="present"
# ['a="present"']
# c="gi bleeding" 106:0 106:1||t="problem"||a="present"
# ['a="present"']
# c="gib" 15:0 15:0||t="problem"||a="present"
# ['a="present"']
# c="guiac positive brown stool" 60:5 60:8||t="problem"||a="present"
# ['a="present"']
# c="any hemetemesis" 26:1 26:2||t="problem"||a="absent"
# ['a="absent"']
# c="pain" 23:15 23:15||t="problem"||a="present"
# ['a="present"']
# c="here rythematous induration" 100:11 100:13||t="problem"||a="present"
# ['a="present"']
# c="cellulitis" 100:16 100:16||t="problem"||a="possible"
# ['a="possible"']
# c="some pus" 80:16 80:17||t="problem"||a="present"
# ['a="present"']
# c="a 5 x 7 cm necrotic area" 80:3 80:9||t="problem"||a="present"
# ['a="present"']
# c="thyromegaly" 78:10 78:10||t="problem"||a="absent"
# ['a="absent"']
# c="metastatic disease" 46:16 46:17||t="problem"||a="absent"
# ['a="absent"']
# c="difficulty with recent memory" 87:11 87:14||t="problem"||a="present"
# ['a="present"']
# c="a decrease in the pretracheal nodes" 51:6 51:11||t="problem"||a="present"
# ['a="present"']
# c="some lymphangitic spread" 51:15 51:17||t="problem"||a="possible"
# ['a="possible"']
# c="some pneumonitis" 51:19 51:20||t="problem"||a="possible"
# ['a="possible"']
# c="edema" 86:3 86:3||t="problem"||a="absent"
# ['a="absent"']
# c="hsm" 83:3 83:3||t="problem"||a="absent"
# ['a="absent"']
# c="siadh" 120:20 120:20||t="problem"||a="possible"
# ['a="possible"']
# c="hyponatremic" 118:6 118:6||t="problem"||a="present"
# ['a="present"']
# c="mycoplasma" 44:7 44:7||t="problem"||a="possible"
# ['a="possible"']
# c="mediastinal recurrence" 46:3 46:4||t="problem"||a="present"
# ['a="present"']
# c="hypovolemia" 120:16 120:16||t="problem"||a="possible"
# ['a="possible"']
# c="lymphadenopathy" 78:8 78:8||t="problem"||a="absent"
# ['a="absent"']
# c="tumor recurrences" 45:22 45:23||t="problem"||a="present"
# ['a="present"']
# c="chlamydia" 44:9 44:9||t="problem"||a="possible"
# ['a="possible"']
# c="pain" 108:8 108:8||t="problem"||a="present"
# ['a="present"']
# c="easy bruis ability" 64:5 64:7||t="problem"||a="present"
# ['a="present"']
# c="diarrhea" 55:5 55:5||t="problem"||a="present"
# ['a="present"']
# c="blood clots in the urine" 53:18 53:22||t="problem"||a="present"
# ['a="present"']
# c="a uti" 53:15 53:16||t="problem"||a="present"
# ['a="present"']
# c="fever" 54:7 54:7||t="problem"||a="present"
# ['a="present"']
# c="nausea" 55:17 55:17||t="problem"||a="present"
# ['a="present"']
# c="vomiting" 55:19 55:19||t="problem"||a="present"
# ['a="present"']
# c="allergic" 65:2 65:2||t="problem"||a="conditional"
# ['a="conditional"']
# c="a rash" 65:8 65:9||t="problem"||a="conditional"
# ['a="conditional"']
# c="confusion" 55:15 55:15||t="problem"||a="present"
# ['a="present"']
# c="utis" 59:0 59:0||t="problem"||a="present"
# ['a="present"']
# c="herpes zoster" 59:14 59:15||t="problem"||a="present"
# ['a="present"']
# c="her left arm lesion" 105:10 105:13||t="problem"||a="present"
# ['a="present"']
# c="neutropenia" 53:9 53:9||t="problem"||a="present"
# ['a="present"']
# c="pain" 105:8 105:8||t="problem"||a="present"
# ['a="present"']
# c="fever" 53:7 53:7||t="problem"||a="present"
# ['a="present"']
# c="obstruction of the right subclavian vein and right brachial cephalic vein" 59:2 59:12||t="problem"||a="present"
# ['a="present"']
# c="elevated" 133:26 133:26||t="problem"||a="present"
# ['a="present"']
# c="carcinoma" 26:14 26:14||t="problem"||a="possible"
# ['a="possible"']
# c="viral pneumonitis" 44:4 44:5||t="problem"||a="possible"
# ['a="possible"']
# c="the pulmonary embolus" 140:2 140:4||t="problem"||a="present"
# ['a="present"']
# c="a left paratracheal adenopathy" 97:4 97:7||t="problem"||a="present"
# ['a="present"']
# c="chest wall nodules" 45:14 45:16||t="problem"||a="present"
# ['a="present"']
# c="pneumonia" 97:17 97:17||t="problem"||a="absent"
# ['a="absent"']
# c="small left pleural effusion" 97:9 97:12||t="problem"||a="present"
# ['a="present"']
# c="the complications" 143:0 143:1||t="problem"||a="present"
# ['a="present"']
# c="the hyponatremia" 143:7 143:8||t="problem"||a="present"
# ['a="present"']
# c="pulmonary embolus" 143:10 143:11||t="problem"||a="present"
# ['a="present"']
# c="the elevatd blood pressure" 143:14 143:17||t="problem"||a="present"
# ['a="present"']
# c="fever" 19:7 19:7||t="problem"||a="present"
# ['a="present"']
# c="myelosuppression" 48:4 48:4||t="problem"||a="present"
# ['a="present"']
# c="fever" 23:6 23:6||t="problem"||a="present"
# ['a="present"']
# c="mucositis" 48:6 48:6||t="problem"||a="present"
# ['a="present"']
# c="klebsiella uti" 49:3 49:4||t="problem"||a="present"
# ['a="present"']
# c="increased shortness of breath" 126:9 126:12||t="problem"||a="present"
# ['a="present"']
# c="chest wall ulceration" 23:8 23:10||t="problem"||a="present"
# ['a="present"']
# c="complications" 48:0 48:0||t="problem"||a="present"
# ['a="present"']
# c="a tender right axillary mass" 24:8 24:12||t="problem"||a="present"
# ['a="present"']
# c="cellulitis" 23:12 23:12||t="problem"||a="present"
# ['a="present"']
# c="a stage iii-a adenocarcinoma of the breast" 37:3 37:9||t="problem"||a="present"
# ['a="present"']
# c="nonproductive cough" 41:16 41:17||t="problem"||a="present"
# ['a="present"']
# c="local and metastatic recurrence" 38:8 38:11||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="her tumor" 38:13 38:14||t="problem"||a="present"
# ['a="present"']
# c="dyspnea" 41:19 41:19||t="problem"||a="conditional"
# ['a="conditional"']
# c="myelosuppression" 40:8 40:8||t="problem"||a="present"
# ['a="present"']
# c="mucositis" 40:6 40:6||t="problem"||a="present"
# ['a="present"']
# c="diffuse interstitial infiltrates" 43:3 43:5||t="problem"||a="present"
# ['a="present"']
# c="tumor" 32:5 32:5||t="problem"||a="absent"
# ['a="absent"']
# c="mild weakness in the left extremities" 88:3 88:8||t="problem"||a="present"
# ['a="present"']
# c="metastatic carcinoma" 32:17 32:18||t="problem"||a="present"
# ['a="present"']
# c="fever" 41:14 41:14||t="problem"||a="present"
# ['a="present"']
# c="her hyponatremia" 133:14 133:15||t="problem"||a="present"
# ['a="present"']
# c="a flu-like illness" 41:8 41:10||t="problem"||a="present"
# ['a="present"']
# c="a large hematoma" 36:3 36:5||t="problem"||a="present"
# ['a="present"']
# c="the other problems" 133:18 133:20||t="problem"||a="present"
# ['a="present"']
# c="miotic" 77:4 77:4||t="problem"||a="present"
# ['a="present"']
# c="a metastatic adenocarcinoma of the breast" 22:9 22:14||t="problem"||a="present"
# ['a="present"']
# c="atypical cells" 27:9 27:10||t="problem"||a="present"
# ['a="present"']
# c="significant edema in both arms" 137:4 137:8||t="problem"||a="present"
# ['a="present"']
# c="some mild edema in the lower extremities" 137:12 137:18||t="problem"||a="present"
# ['a="present"']
# c="trace ketones" 96:5 96:6||t="problem"||a="present"
# ['a="present"']
# c="trace protein" 96:2 96:3||t="problem"||a="present"
# ['a="present"']
# c="4 to 6 wbcs" 96:15 96:18||t="problem"||a="present"
# ['a="present"']
# c="no voluntary movement" 85:4 85:6||t="problem"||a="present"
# ['a="present"']
# c="positive for bilirubin and nitrogen" 96:8 96:12||t="problem"||a="present"
# ['a="present"']
# c="a 5.5 cm poorly differentiated , grade iii out of iii infiltrating ductal carcinoma" 31:6 31:19||t="problem"||a="present"
# ['a="present"']
# c="very swollen" 84:6 84:7||t="problem"||a="present"
# ['a="present"']
# c="1+ bacteria" 96:20 96:21||t="problem"||a="present"
# ['a="present"']
# c="tender" 78:2 78:2||t="problem"||a="present"
# ['a="present"']
# c="metastatic breast cell ca" 98:12 98:15||t="problem"||a="present"
# ['a="present"']
# c="degenerative joint disease in the shoulders and lumbar spine" 29:3 29:11||t="problem"||a="present"
# ['a="present"']
# c="increased radio chaser uptake in the breast bilaterally" 29:15 29:22||t="problem"||a="present"
# ['a="present"']
# c="very weak" 148:2 148:3||t="problem"||a="present"
# ['a="present"']
# c="metastatic cancer" 33:15 33:16||t="problem"||a="possible"
# ['a="possible"']
# c="hampton &apos;s hump" 126:32 126:34||t="problem"||a="present"
# ['a="present"']
# c="the bilateral edema" 148:16 148:18||t="problem"||a="present"
# ['a="present"']
# c="a mass on the right pectoralis muscle" 33:3 33:9||t="problem"||a="present"
# ['a="present"']
# c="extensive lymphatic vessel invasion" 34:16 34:19||t="problem"||a="present"
# ['a="present"']
# c="5.5 cm poorly differentiated infiltrating ductal and intraductal carcinoma" 34:6 34:14||t="problem"||a="present"
# ['a="present"']
# c="nausea" 19:3 19:3||t="problem"||a="present"
# ['a="present"']
# c="the diarrhea" 99:7 99:8||t="problem"||a="present"
# ['a="present"']
# c="diarrhea" 19:1 19:1||t="problem"||a="present"
# ['a="present"']
# c="her hyponatremia" 121:5 121:6||t="problem"||a="present"
# ['a="present"']
# c="hyponatremia" 17:1 17:1||t="problem"||a="present"
# ['a="present"']
# c="an erythema on her left chest wall" 98:45 98:51||t="problem"||a="present"
# ['a="present"']
# c="pulmonary embolus" 18:1 18:2||t="problem"||a="present"
# ['a="present"']
# c="metastatic adenocarcinoma of the breast" 15:0 15:4||t="problem"||a="present"
# ['a="present"']
# c="a wedge shaped infiltrate in the right upper lobe" 126:19 126:27||t="problem"||a="present"
# ['a="present"']
# c="the rash in her left groin area" 145:22 145:28||t="problem"||a="present"
# ['a="present"']
# c="vomiting" 19:5 19:5||t="problem"||a="present"
# ['a="present"']
# c="vomiting" 98:38 98:38||t="problem"||a="present"
# ['a="present"']
# c="diarrhea" 98:34 98:34||t="problem"||a="present"
# ['a="present"']
# c="nausea" 98:36 98:36||t="problem"||a="present"
# ['a="present"']
# c="fever" 98:29 98:29||t="problem"||a="present"
# ['a="present"']
# c="bilateral breast masses" 26:8 26:10||t="problem"||a="present"
# ['a="present"']
# c="pe" 127:12 127:12||t="problem"||a="possible"
# ['a="possible"']
# c="her clouded thinking" 114:21 114:23||t="problem"||a="present"
# ['a="present"']
# c="altered mental status" 114:25 114:27||t="problem"||a="present"
# ['a="present"']
# c="elevated" 116:6 116:6||t="problem"||a="present"
# ['a="present"']
# c="pain" 113:34 113:34||t="problem"||a="present"
# ['a="present"']
# c="enhancing lesions" 115:12 115:13||t="problem"||a="absent"
# ['a="absent"']
# c="her difficulty breathing" 152:19 152:21||t="problem"||a="present"
# ['a="present"']
# c="metastatic breast cancer" 58:2 58:4||t="problem"||a="present"
# ['a="present"']
# c="fever" 58:8 58:8||t="problem"||a="present"
# ['a="present"']
# c="neutropenia" 58:10 58:10||t="problem"||a="present"
# ['a="present"']
# c="elevated" 94:2 94:2||t="problem"||a="present"
# ['a="present"']
# c="her pain" 152:15 152:16||t="problem"||a="present"
# ['a="present"']
# c="her pain" 113:15 113:16||t="problem"||a="present"
# ['a="present"']
# c="a little dry" 138:3 138:5||t="problem"||a="present"
# ['a="present"']
# c="hallucinations" 94:9 94:9||t="problem"||a="present"
# ['a="present"']
# c="confusion" 94:7 94:7||t="problem"||a="present"
# ['a="present"']
# c="some mental status changes" 94:2 94:5||t="problem"||a="present"
# ['a="present"']
# c="pericardial effusion" 83:18 83:19||t="problem"||a="present"
# ['a="present"']
# c="further hallucinations" 96:3 96:4||t="problem"||a="absent"
# ['a="absent"']
# c="the mental status changes" 95:13 95:16||t="problem"||a="present"
# ['a="present"']
# c="ectopic p" 63:27 63:28||t="problem"||a="possible"
# ['a="possible"']
# c="bilateral cystic adnexal masses" 25:11 25:14||t="problem"||a="present"
# ['a="present"']
# c="wheezing" 90:7 90:7||t="problem"||a="present"
# ['a="present"']
# c="the patient &apos;s shortness of breath" 90:0 90:5||t="problem"||a="present"
# ['a="present"']
# c="symptoms" 98:22 98:22||t="problem"||a="present"
# ['a="present"']
# c="anxiety" 98:24 98:24||t="problem"||a="present"
# ['a="present"']
# c="decreased function of the left kidney" 83:25 83:30||t="problem"||a="present"
# ['a="present"']
# c="steroid acne" 88:11 88:12||t="problem"||a="possible"
# ['a="possible"']
# c="multiple liver metastases" 83:21 83:23||t="problem"||a="present"
# ['a="present"']
# c="symptoms" 103:72 103:72||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="her shortness of breath" 99:7 99:10||t="problem"||a="present"
# ['a="present"']
# c="metastatic cervical cancer" 21:12 21:14||t="problem"||a="present"
# ['a="present"']
# c="tamponade" 92:21 92:21||t="problem"||a="absent"
# ['a="absent"']
# c="liver and spleen metastases" 17:11 17:14||t="problem"||a="present"
# ['a="present"']
# c="decreased po2" 94:16 94:17||t="problem"||a="possible"
# ['a="possible"']
# c="masses" 53:6 53:6||t="problem"||a="absent"
# ['a="absent"']
# c="masses" 55:1 55:1||t="problem"||a="absent"
# ['a="absent"']
# c="a hydronephrosis" 38:30 38:31||t="problem"||a="present"
# ['a="present"']
# c="fairly significant aa gradient" 74:21 74:24||t="problem"||a="present"
# ['a="present"']
# c="wheezing" 29:15 29:15||t="problem"||a="present"
# ['a="present"']
# c="lymphadenopathy" 47:1 47:1||t="problem"||a="absent"
# ['a="absent"']
# c="murmur" 51:10 51:10||t="problem"||a="absent"
# ['a="absent"']
# c="shortness of breath" 28:12 28:14||t="problem"||a="present"
# ['a="present"']
# c="asthma" 70:13 70:13||t="problem"||a="absent"
# ['a="absent"']
# c="pericardial involvement" 72:11 72:12||t="problem"||a="possible"
# ['a="possible"']
# c="infectious" 72:14 72:14||t="problem"||a="possible"
# ['a="possible"']
# c="other cardiovascular causes" 72:16 72:18||t="problem"||a="possible"
# ['a="possible"']
# c="viral bronchiolitis" 72:21 72:22||t="problem"||a="possible"
# ['a="possible"']
# c="a dry non-productive cough" 28:16 28:19||t="problem"||a="present"
# ['a="present"']
# c="malignant" 33:18 33:18||t="problem"||a="possible"
# ['a="possible"']
# c="the pericardial effusion" 33:9 33:11||t="problem"||a="present"
# ['a="present"']
# c="cervical cancer" 33:6 33:7||t="problem"||a="present"
# ['a="present"']
# c="a malignant lymphangitic spread" 72:6 72:9||t="problem"||a="possible"
# ['a="possible"']
# c="pulmonary wheezing" 70:4 70:5||t="problem"||a="present"
# ['a="present"']
# c="well healed pfannenstiel scars" 53:0 53:3||t="problem"||a="present"
# ['a="present"']
# c="tumor" 27:4 27:4||t="problem"||a="absent"
# ['a="absent"']
# c="rubs" 51:8 51:8||t="problem"||a="absent"
# ['a="absent"']
# c="peritubal and periovarian adhesions" 27:7 27:10||t="problem"||a="present"
# ['a="present"']
# c="tachycardia" 51:5 51:5||t="problem"||a="present"
# ['a="present"']
# c="pericardial effusion" 32:9 32:10||t="problem"||a="present"
# ['a="present"']
# c="a 10 mm pulsus paradoxus" 32:12 32:16||t="problem"||a="present"
# ['a="present"']
# c="tamponade" 32:24 32:24||t="problem"||a="absent"
# ['a="absent"']
# c="few inspiratory wheezes" 49:0 49:2||t="problem"||a="present"
# ['a="present"']
# c="a rub" 76:4 76:5||t="problem"||a="present"
# ['a="present"']
# c="sinus tachycardia" 32:2 32:3||t="problem"||a="present"
# ['a="present"']
# c="rhonchi" 49:5 49:5||t="problem"||a="absent"
# ['a="absent"']
# c="dry mucous membranes" 45:0 45:2||t="problem"||a="present"
# ['a="present"']
# c="metastatic squamous cell carcinoma in the cardinal ligaments" 23:16 23:23||t="problem"||a="present"
# ['a="present"']
# c="extensive lymphatic invasion" 23:25 23:27||t="problem"||a="present"
# ['a="present"']
# c="poorly differentiated squamous cell carcinoma of the cervix" 23:2 23:9||t="problem"||a="present"
# ['a="present"']
# c="tamponade" 66:5 66:5||t="problem"||a="absent"
# ['a="absent"']
# c="metastatic cervical cancer" 65:18 65:20||t="problem"||a="possible"
# ['a="possible"']
# c="metastatic cervical cancer" 85:2 85:4||t="problem"||a="present"
# ['a="present"']
# c="stage 2b disease" 24:5 24:7||t="problem"||a="present"
# ['a="present"']
# c="numerous erythematous maculopapules on her back" 87:9 87:14||t="problem"||a="present"
# ['a="present"']
# c="lymphangitic spread" 84:7 84:8||t="problem"||a="possible"
# ['a="possible"']
# c="a new pericardial effusion" 65:5 65:8||t="problem"||a="present"
# ['a="present"']
# c="mild respiratory distress" 42:4 42:6||t="problem"||a="present"
# ['a="present"']
# c="pulmonary lymphangitic spread" 17:6 17:8||t="problem"||a="present"
# ['a="present"']
# c="periaortic lymphadenopathy" 83:42 83:43||t="problem"||a="present"
# ['a="present"']
# c="dilated left intrarenal collecting system and proximal ureter" 83:32 83:39||t="problem"||a="present"
# ['a="present"']
# c="asthma" 30:13 30:13||t="problem"||a="possible"
# ['a="possible"']
# c="pulmonary nodules in the chest" 83:12 83:16||t="problem"||a="possible"
# ['a="possible"']
# c="cyanosis" 59:3 59:3||t="problem"||a="absent"
# ['a="absent"']
# c="masses" 57:1 57:1||t="problem"||a="absent"
# ['a="absent"']
# c="edema" 59:1 59:1||t="problem"||a="absent"
# ['a="absent"']
# c="diastolic indications of the right ventricle" 68:11 68:16||t="problem"||a="present"
# ['a="present"']
# c="low velocity paradox" 68:18 68:20||t="problem"||a="present"
# ['a="present"']
# c="myotic pupils" 45:4 45:5||t="problem"||a="present"
# ['a="present"']
# c="moderate anterior pericardial effusion" 68:2 68:5||t="problem"||a="present"
# ['a="present"']
# c="malignant pericardial effusion" 21:20 21:22||t="problem"||a="possible"
# ['a="possible"']
# c="tamponade" 69:5 69:5||t="problem"||a="absent"
# ['a="absent"']
# c="tamponade" 91:14 91:14||t="problem"||a="absent"
# ['a="absent"']
# c="a new rub" 75:25 75:27||t="problem"||a="possible"
# ['a="possible"']
# c="a new junctional rhythm" 75:17 75:20||t="problem"||a="present"
# ['a="present"']
# c="murmur" 75:29 75:29||t="problem"||a="possible"
# ['a="possible"']
# c="an ectopic low atrial p" 77:2 77:6||t="problem"||a="present"
# ['a="present"']
# c="tamponade" 77:17 77:17||t="problem"||a="absent"
# ['a="absent"']
# c="pericardial effusion" 17:3 17:4||t="problem"||a="present"
# ['a="present"']
# c="moderate to mild effusion" 79:17 79:20||t="problem"||a="present"
# ['a="present"']
# c="the effusion" 79:44 79:45||t="problem"||a="present"
# ['a="present"']
# c="low normal function" 79:13 79:15||t="problem"||a="present"
# ['a="present"']
# c="lymphangitic spread" 83:2 83:3||t="problem"||a="present"
# ['a="present"']
# c="cancer in the chest" 83:5 83:8||t="problem"||a="present"
# ['a="present"']
# c="a 4x3.6x2 cm cervical mass" 22:9 22:13||t="problem"||a="present"
# ['a="present"']
# c="a fibroid" 22:17 22:18||t="problem"||a="possible"
# ['a="possible"']
# c="metastatic cervical carcinoma" 16:0 16:2||t="problem"||a="present"
# ['a="present"']
# c="elevated" 34:20 34:20||t="problem"||a="present"
# ['a="present"']
# c="an myocardial infarction" 32:29 32:31||t="problem"||a="present"
# ['a="present"']
# c="respiratory failure" 36:12 36:13||t="problem"||a="present"
# ['a="present"']
# c="the thymoma" 47:14 47:15||t="problem"||a="present"
# ['a="present"']
# c="shortness of breath" 36:5 36:7||t="problem"||a="present"
# ['a="present"']
# c="chronic obstructive pulmonary disease" 32:14 32:17||t="problem"||a="present"
# ['a="present"']
# c="thymoma" 32:9 32:9||t="problem"||a="present"
# ['a="present"']
# c="hypothyroidism" 32:19 32:19||t="problem"||a="present"
# ['a="present"']
# c="scar tissue" 49:6 49:7||t="problem"||a="possible"
# ['a="possible"']
# c="hydrocele" 22:1 22:1||t="problem"||a="present"
# ['a="present"']
# c="left lower lobe infiltrate" 34:12 34:15||t="problem"||a="present"
# ['a="present"']
# c="respiratory distress" 33:21 33:22||t="problem"||a="present"
# ['a="present"']
# c="shortness of breath" 33:3 33:5||t="problem"||a="present"
# ['a="present"']
# c="benign prostatic hypertrophy" 21:1 21:3||t="problem"||a="present"
# ['a="present"']
# c="colon cancer" 20:3 20:4||t="problem"||a="present"
# ['a="present"']
# c="hypertension" 19:1 19:1||t="problem"||a="present"
# ['a="present"']
# c="difficulty lifting his arms" 37:4 37:7||t="problem"||a="present"
# ['a="present"']
# c="myasthenia gravis" 15:0 15:1||t="problem"||a="present"
# ['a="present"']
# c="hypothyroidism" 17:1 17:1||t="problem"||a="present"
# ['a="present"']
# c="thymoma" 18:3 18:3||t="problem"||a="present"
# ['a="present"']
# c="dysphasia" 38:6 38:6||t="problem"||a="present"
# ['a="present"']
# c="myasthenia gravis" 40:13 40:14||t="problem"||a="present"
# ['a="present"']
# c="thymoma" 40:20 40:20||t="problem"||a="present"
# ['a="present"']
# c="weakness in the proximal muscles" 39:6 39:10||t="problem"||a="present"
# ['a="present"']
# c="disease" 35:22 35:22||t="problem"||a="absent"
# ['a="absent"']
# c="diplopia" 38:10 38:10||t="problem"||a="present"
# ['a="present"']
# c="difficult access problems" 19:4 19:6||t="problem"||a="present"
# ['a="present"']
# c="end stage renal disease" 16:9 16:12||t="problem"||a="present"
# ['a="present"']
# c="this difficult access problem" 20:8 20:11||t="problem"||a="present"
# ['a="present"']
# c="bleed" 25:17 25:17||t="problem"||a="present"
# ['a="present"']
# c="rupture" 18:21 18:21||t="problem"||a="present"
# ['a="present"']
# c="polycystic kidneydisease" 17:4 17:5||t="problem"||a="present"
# ['a="present"']
# c="hypertension" 23:2 23:2||t="problem"||a="present"
# ['a="present"']
# c="pneumonia" 23:17 23:17||t="problem"||a="present"
# ['a="present"']
# c="pneumonia" 21:8 21:8||t="problem"||a="present"
# ['a="present"']
# c="high" 74:3 74:3||t="problem"||a="present"
# ['a="present"']
# c="both cystic and solid components" 26:16 26:20||t="problem"||a="present"
# ['a="present"']
# c="an 8 cm left lower quadrant mass" 26:8 26:14||t="problem"||a="present"
# ['a="present"']
# c="the patient &apos;s pain" 29:3 29:6||t="problem"||a="present"
# ['a="present"']
# c="adhesions" 63:21 63:21||t="problem"||a="present"
# ['a="present"']
# c="a pelvic mass" 39:11 39:13||t="problem"||a="present"
# ['a="present"']
# c="still elevated" 74:23 74:24||t="problem"||a="present"
# ['a="present"']
# c="pain" 27:10 27:10||t="problem"||a="present"
# ['a="present"']
# c="hypotension" 86:5 86:5||t="problem"||a="present"
# ['a="present"']
# c="respiratory insufficiency" 86:9 86:10||t="problem"||a="present"
# ['a="present"']
# c="anemia" 37:8 37:8||t="problem"||a="present"
# ['a="present"']
# c="low stoma output" 90:13 90:15||t="problem"||a="present"
# ['a="present"']
# c="an enterotomy" 63:40 63:41||t="problem"||a="present"
# ['a="present"']
# c="asthma" 37:10 37:10||t="problem"||a="present"
# ['a="present"']
# c="anxiety" 79:22 79:22||t="problem"||a="present"
# ['a="present"']
# c="hypertension" 37:4 37:4||t="problem"||a="present"
# ['a="present"']
# c="tachycardia" 81:18 81:18||t="problem"||a="present"
# ['a="present"']
# c="bilious fluid within the peritoneum" 84:25 84:29||t="problem"||a="present"
# ['a="present"']
# c="a small bowel enterotomy" 84:17 84:20||t="problem"||a="present"
# ['a="present"']
# c="hypercholesterolemia" 37:6 37:6||t="problem"||a="present"
# ['a="present"']
# c="increased free air under the diaphragm" 82:4 82:9||t="problem"||a="present"
# ['a="present"']
# c="abdominal pain" 81:20 81:21||t="problem"||a="present"
# ['a="present"']
# c="increased shortness of breath" 81:13 81:16||t="problem"||a="present"
# ['a="present"']
# c="free air" 83:7 83:8||t="problem"||a="present"
# ['a="present"']
# c="hypothyroidism" 37:0 37:0||t="problem"||a="present"
# ['a="present"']
# c="arthritis" 37:2 37:2||t="problem"||a="present"
# ['a="present"']
# c="another peroration" 85:28 85:29||t="problem"||a="present"
# ['a="present"']
# c="a vaginal tumor" 63:33 63:35||t="problem"||a="present"
# ['a="present"']
# c="an inability to tolerate p.o. intake" 29:20 29:25||t="problem"||a="present"
# ['a="present"']
# c="a similar increased abdominal pain episode" 85:8 85:13||t="problem"||a="present"
# ['a="present"']
# c="psychiatric issues" 79:24 79:25||t="problem"||a="present"
# ['a="present"']
# c="the site of previous repair" 85:31 85:35||t="problem"||a="present"
# ['a="present"']
# c="infectious disease" 96:1 96:2||t="problem"||a="present"
# ['a="present"']
# c="the pelvic mass" 63:15 63:17||t="problem"||a="present"
# ['a="present"']
# c="pain" 66:5 66:5||t="problem"||a="present"
# ['a="present"']
# c="dvt" 62:11 62:11||t="problem"||a="absent"
# ['a="absent"']
# c="pe" 62:13 62:13||t="problem"||a="absent"
# ['a="absent"']
# c="fever" 103:17 103:17||t="problem"||a="absent"
# ['a="absent"']
# c="baseline hypertension" 70:3 70:4||t="problem"||a="present"
# ['a="present"']
# c="other symptoms" 103:19 103:20||t="problem"||a="absent"
# ['a="absent"']
# c="c. perfringens" 60:6 60:7||t="problem"||a="present"
# ['a="present"']
# c="c. perfringens" 97:7 97:8||t="problem"||a="present"
# ['a="present"']
# c="bleeding" 31:9 31:9||t="problem"||a="absent"
# ['a="absent"']
# c="tumor in the left lower quadrant" 59:18 59:23||t="problem"||a="possible"
# ['a="possible"']
# c="abscess" 59:16 59:16||t="problem"||a="possible"
# ['a="possible"']
# c="vaginal discharge" 31:6 31:7||t="problem"||a="absent"
# ['a="absent"']
# c="rectosigmoid mass" 59:7 59:8||t="problem"||a="possible"
# ['a="possible"']
# c="fistula" 59:10 59:10||t="problem"||a="possible"
# ['a="possible"']
# c="chills" 31:3 31:3||t="problem"||a="absent"
# ['a="absent"']
# c="fevers" 31:1 31:1||t="problem"||a="absent"
# ['a="absent"']
# c="the left lower quadrant pain in the groin" 30:0 30:7||t="problem"||a="present"
# ['a="present"']
# c="vomiting" 29:18 29:18||t="problem"||a="present"
# ['a="present"']
# c="nausea" 29:16 29:16||t="problem"||a="present"
# ['a="present"']
# c="throat edema" 54:7 54:8||t="problem"||a="conditional"
# ['a="conditional"']
# c="the mass" 24:4 24:5||t="problem"||a="present"
# ['a="present"']
# c="growth" 110:6 110:6||t="problem"||a="absent"
# ['a="absent"']
# c="hypothyroidism" 115:4 115:4||t="problem"||a="present"
# ['a="present"']
# c="her allergies" 54:0 54:1||t="problem"||a="present"
# ['a="present"']
# c="severe left lower quadrant pain" 25:3 25:7||t="problem"||a="present"
# ['a="present"']
# c="a right ij clot" 111:10 111:13||t="problem"||a="present"
# ['a="present"']
# c="pelvic mass" 5:0 5:1||t="problem"||a="present"
# ['a="present"']
# c="erythema" 108:9 108:9||t="problem"||a="present"
# ['a="present"']
# c="depression poorly controlled" 67:5 67:7||t="problem"||a="present"
# ['a="present"']
# c="anxious" 67:3 67:3||t="problem"||a="present"
# ['a="present"']
# c="pelvic mass" 19:0 19:1||t="problem"||a="present"
# ['a="present"']
# c="hypertension" 21:1 21:1||t="problem"||a="present"
# ['a="present"']
# c="a pelvic mass" 23:11 23:13||t="problem"||a="present"
# ['a="present"']
# c="rheumatoid arthritis" 24:18 24:19||t="problem"||a="present"
# ['a="present"']
# c="presyncope" 24:27 24:27||t="problem"||a="present"
# ['a="present"']
# c="dizziness intermittently" 25:3 25:4||t="problem"||a="present"
# ['a="present"']
# c="dizziness" 17:2 17:2||t="problem"||a="present"
# ['a="present"']
# c="tired" 45:7 45:7||t="problem"||a="present"
# ['a="present"']
# c="presyncope" 16:2 16:2||t="problem"||a="present"
# ['a="present"']
# c="apparent distress" 45:4 45:5||t="problem"||a="absent"
# ['a="absent"']
# c="bright red blood per rectum" 37:5 37:9||t="problem"||a="absent"
# ['a="absent"']
# c="left ventricular hypertrophy" 20:19 20:21||t="problem"||a="present"
# ['a="present"']
# c="melena" 37:3 37:3||t="problem"||a="absent"
# ['a="absent"']
# c="emesis" 37:12 37:12||t="problem"||a="absent"
# ['a="absent"']
# c="iron deficiency anemia" 19:2 19:4||t="problem"||a="present"
# ['a="present"']
# c="the discrepancy" 94:0 94:1||t="problem"||a="present"
# ['a="present"']
# c="the patient &apos;s presyncopal symptoms" 92:4 92:8||t="problem"||a="present"
# ['a="present"']
# c="fevers" 37:15 37:15||t="problem"||a="absent"
# ['a="absent"']
# c="heart failure" 24:13 24:14||t="problem"||a="present"
# ['a="present"']
# c="diastolic function" 24:10 24:11||t="problem"||a="present"
# ['a="present"']
# c="anemia" 38:6 38:6||t="problem"||a="present"
# ['a="present"']
# c="chills" 37:17 37:17||t="problem"||a="absent"
# ['a="absent"']
# c="diastolic dysfunction" 20:4 20:5||t="problem"||a="present"
# ['a="present"']
# c="her increased blood pressure" 90:8 90:11||t="problem"||a="present"
# ['a="present"']
# c="a systolic murmur" 34:3 34:5||t="problem"||a="present"
# ['a="present"']
# c="a decreased left radial pulse" 34:13 34:17||t="problem"||a="present"
# ['a="present"']
# c="a proximal left subclavian artery stenosis" 95:16 95:21||t="problem"||a="present"
# ['a="present"']
# c="mild lateral ischemia" 91:12 91:14||t="problem"||a="present"
# ['a="present"']
# c="an old right cerebellar infarct" 98:12 98:16||t="problem"||a="possible"
# ['a="possible"']
# c="a small vessel disease" 98:5 98:8||t="problem"||a="present"
# ['a="present"']
# c="loss of consciousness" 26:9 26:11||t="problem"||a="absent"
# ['a="absent"']
# c="palpitations" 26:14 26:14||t="problem"||a="absent"
# ['a="absent"']
# c="significant carotid disease" 99:9 99:11||t="problem"||a="absent"
# ['a="absent"']
# c="chest pain" 26:16 26:17||t="problem"||a="absent"
# ['a="absent"']
# c="a decreased flow" 96:5 96:7||t="problem"||a="present"
# ['a="present"']
# c="subclavian steal phenomenon" 96:21 96:23||t="problem"||a="possible"
# ['a="possible"']
# c="native vessel disease" 96:11 96:13||t="problem"||a="possible"
# ['a="possible"']
# c="some degree of retrograde flow" 96:15 96:19||t="problem"||a="possible"
# ['a="possible"']
# c="loss of consciousness" 28:3 28:5||t="problem"||a="absent"
# ['a="absent"']
# c="bowel or bladder incontinence" 28:8 28:11||t="problem"||a="absent"
# ['a="absent"']
# c="the patient &apos;s intervascular disease" 102:19 102:23||t="problem"||a="present"
# ['a="present"']
# c="a right sided pubic rami fracture" 106:4 106:9||t="problem"||a="present"
# ['a="present"']
# c="subclavian steal phenomenon" 101:15 101:17||t="problem"||a="absent"
# ['a="absent"']
# c="the patient &apos;s symptoms" 101:7 101:10||t="problem"||a="present"
# ['a="present"']
# c="antegrade flow" 100:7 100:8||t="problem"||a="present"
# ['a="present"']
# c="bilateral bilateral renal bruits" 54:4 54:7||t="problem"||a="present"
# ['a="present"']
# c="her described vertigo" 112:6 112:8||t="problem"||a="present"
# ['a="present"']
# c="frequent vomiting" 113:5 113:6||t="problem"||a="conditional"
# ['a="conditional"']
# c="dysrhythmia" 112:20 112:20||t="problem"||a="absent"
# ['a="absent"']
# c="femoral bruits" 54:9 54:10||t="problem"||a="present"
# ['a="present"']
# c="edema" 56:3 56:3||t="problem"||a="absent"
# ['a="absent"']
# c="bilateral bruits" 49:4 49:5||t="problem"||a="present"
# ['a="present"']
# c="an occult hip fracture" 108:9 108:12||t="problem"||a="absent"
# ['a="absent"']
# c="jugular venous distension" 50:3 50:5||t="problem"||a="absent"
# ['a="absent"']
# c="her rami fracture" 110:15 110:17||t="problem"||a="present"
# ['a="present"']
# c="few bibasilar crackles" 51:14 51:16||t="problem"||a="present"
# ['a="present"']
# c="5-10 white blood cells" 66:6 66:9||t="problem"||a="present"
# ['a="present"']
# c="myocardial infarction" 86:7 86:8||t="problem"||a="possible"
# ['a="possible"']
# c="visual changes" 26:5 26:6||t="problem"||a="absent"
# ['a="absent"']
# c="borderline left atrial enlargement" 67:10 67:13||t="problem"||a="present"
# ['a="present"']
# c="t-wave inversions in v4" 67:18 67:21||t="problem"||a="present"
# ['a="present"']
# c="borderline left ventricular hypertrophy" 67:29 67:32||t="problem"||a="present"
# ['a="present"']
# c="strain" 67:34 67:34||t="problem"||a="present"
# ['a="present"']
# c="nosocomial urinary tract infection" 123:17 123:20||t="problem"||a="possible"
# ['a="possible"']
# c="some urinary incontinence" 121:4 121:6||t="problem"||a="present"
# ['a="present"']
# c="s4" 52:30 52:30||t="problem"||a="absent"
# ['a="absent"']
# c="trace leukocyte esterase" 66:2 66:4||t="problem"||a="present"
# ['a="present"']
# c="1+ squamous epithelial cells" 66:11 66:14||t="problem"||a="present"
# ['a="present"']
# c="2/6 cresendo / descrecendo murmur" 52:9 52:13||t="problem"||a="present"
# ['a="present"']
# c="s3" 52:28 52:28||t="problem"||a="absent"
# ['a="absent"']
# c="hepatosplenomegaly" 53:14 53:14||t="problem"||a="absent"
# ['a="absent"']
# c="non-distended" 53:7 53:7||t="problem"||a="absent"
# ['a="absent"']
# c="a subclavian artery stenosis" 94:16 94:19||t="problem"||a="present"
# ['a="present"']
# c="bilateral holosystolic bruits over the subclavians" 51:2 51:7||t="problem"||a="present"
# ['a="present"']
# c="non-tender" 53:5 53:5||t="problem"||a="absent"
# ['a="absent"']
# c="abdominal tenderness" 53:17 53:18||t="problem"||a="absent"
# ['a="absent"']
# c="a left cataract" 48:2 48:4||t="problem"||a="present"
# ['a="present"']
# c="left ventricular hypertrophy" 88:12 88:14||t="problem"||a="present"
# ['a="present"']
# c="significant valvular abnormalities" 88:17 88:19||t="problem"||a="absent"
# ['a="absent"']
# c="emesis" 115:5 115:5||t="problem"||a="present"
# ['a="present"']
# c="a new t-wave inversion" 68:4 68:7||t="problem"||a="present"
# ['a="present"']
# c="spontaneous emesis" 114:7 114:8||t="problem"||a="conditional"
# ['a="conditional"']
# c="dysrhythmia" 87:12 87:12||t="problem"||a="absent"
# ['a="absent"']
# c="the patient &apos;s emesis" 116:0 116:3||t="problem"||a="present"
# ['a="present"']
# c="bilious" 116:8 116:8||t="problem"||a="present"
# ['a="present"']
# c="new or old blood" 116:12 116:15||t="problem"||a="absent"
# ['a="absent"']
# c="a 50 point discrepancy" 29:14 29:17||t="problem"||a="present"
# ['a="present"']
# c="mediastinal widening" 31:4 31:5||t="problem"||a="absent"
# ['a="absent"']
# c="vertigo" 118:15 118:15||t="problem"||a="present"
# ['a="present"']
# c="the patient &apos;s nausea" 117:3 117:6||t="problem"||a="present"
# ['a="present"']
# c="an anatomical lesion of her gastrointestinal tract" 117:24 117:30||t="problem"||a="absent"
# ['a="absent"']
# c="dissection" 35:9 35:9||t="problem"||a="absent"
# ['a="absent"']
# c="congestive heart failure" 35:13 35:15||t="problem"||a="absent"
# ['a="absent"']
# c="her nausea" 118:12 118:13||t="problem"||a="present"
# ['a="present"']
# c="diastolic congestive heart failure" 20:35 20:38||t="problem"||a="present"
# ['a="present"']
# c="hypothyroidism" 21:2 21:2||t="problem"||a="present"
# ['a="present"']
# c="a likely urinary tract infection" 122:2 122:6||t="problem"||a="possible"
# ['a="possible"']
# c="hypertension" 24:16 24:16||t="problem"||a="present"
# ['a="present"']
# c="minor head trauma" 27:30 27:32||t="problem"||a="present"
# ['a="present"']
# c="rheumatoid arthritis" 22:2 22:3||t="problem"||a="present"
# ['a="present"']
# c="a mild increase" 126:3 126:5||t="problem"||a="present"
# ['a="present"']
# c="syncope" 6:0 6:0||t="problem"||a="present"
# ['a="present"']
# c="shortness of breath" 26:20 26:22||t="problem"||a="absent"
# ['a="absent"']
# c="dizzy" 27:21 27:21||t="problem"||a="conditional"
# ['a="conditional"']
# c="cutaneous lupus ( mixed connective tissue disease )" 22:5 22:12||t="problem"||a="present"
# ['a="present"']
# c="diaphoresis" 26:24 26:24||t="problem"||a="absent"
# ['a="absent"']
# c="faint" 25:18 25:18||t="problem"||a="present"
# ['a="present"']
# c="mild pain in right hip" 111:6 111:10||t="problem"||a="conditional"
# ['a="conditional"']
# c="pain" 100:10 100:10||t="problem"||a="present"
# ['a="present"']
# c="pain" 34:15 34:15||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="head trauma" 90:5 90:6||t="problem"||a="absent"
# ['a="absent"']
# c="urinary incontinence" 70:12 70:13||t="problem"||a="present"
# ['a="present"']
# c="right le pain" 50:7 50:9||t="problem"||a="present"
# ['a="present"']
# c="afebrile" 88:2 88:2||t="problem"||a="absent"
# ['a="absent"']
# c="scleral icterus" 91:3 91:4||t="problem"||a="absent"
# ['a="absent"']
# c="rashes" 97:17 97:17||t="problem"||a="absent"
# ['a="absent"']
# c="excesive sedation" 34:0 34:1||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="chest pain" 67:2 67:3||t="problem"||a="absent"
# ['a="absent"']
# c="pain" 32:16 32:16||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="the pain" 68:2 68:3||t="problem"||a="present"
# ['a="present"']
# c="a shock like intensity down the right leg" 68:12 68:19||t="problem"||a="present"
# ['a="present"']
# c="lymphadenopathy" 93:6 93:6||t="problem"||a="absent"
# ['a="absent"']
# c="hypercholesterolemia" 73:5 73:5||t="problem"||a="present"
# ['a="present"']
# c="vomiting" 124:8 124:8||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="non-insulin-requiring diabetes mellitus" 73:0 73:2||t="problem"||a="present"
# ['a="present"']
# c="fevers" 124:3 124:3||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="any changes in bowel habits" 71:2 71:6||t="problem"||a="absent"
# ['a="absent"']
# c="nka" 46:0 46:0||t="problem"||a="absent"
# ['a="absent"']
# c="r leg pain" 48:0 48:2||t="problem"||a="present"
# ['a="present"']
# c="nontender" 96:5 96:5||t="problem"||a="absent"
# ['a="absent"']
# c="headache" 31:11 31:11||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="severe low back pain" 60:2 60:5||t="problem"||a="present"
# ['a="present"']
# c="somewhat uncomfortable" 87:9 87:10||t="problem"||a="present"
# ['a="present"']
# c="pain" 87:13 87:13||t="problem"||a="present"
# ['a="present"']
# c="the pain" 62:16 62:17||t="problem"||a="present"
# ['a="present"']
# c="masses" 96:8 96:8||t="problem"||a="absent"
# ['a="absent"']
# c="an infectious process" 107:10 107:12||t="problem"||a="absent"
# ['a="absent"']
# c="lumbar tenderness" 102:5 102:6||t="problem"||a="present"
# ['a="present"']
# c="point tenderness" 102:9 102:10||t="problem"||a="absent"
# ['a="absent"']
# c="gallops" 95:10 95:10||t="problem"||a="absent"
# ['a="absent"']
# c="worsening low back pain" 63:4 63:7||t="problem"||a="present"
# ['a="present"']
# c="numbness" 64:2 64:2||t="problem"||a="absent"
# ['a="absent"']
# c="afebrile" 108:2 108:2||t="problem"||a="absent"
# ['a="absent"']
# c="right le pain" 5:0 5:2||t="problem"||a="present"
# ['a="present"']
# c="rubs" 95:7 95:7||t="problem"||a="absent"
# ['a="absent"']
# c="positive" 100:15 100:15||t="problem"||a="possible"
# ['a="possible"']
# c="this problem" 61:5 61:6||t="problem"||a="present"
# ['a="present"']
# c="pain" 31:9 31:9||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="murmurs" 95:5 95:5||t="problem"||a="absent"
# ['a="absent"']
# c="lesions" 97:14 97:14||t="problem"||a="absent"
# ['a="absent"']
# c="l4/5 facet enhancement" 105:6 105:8||t="problem"||a="present"
# ['a="present"']
# c="fever" 65:2 65:2||t="problem"||a="absent"
# ['a="absent"']
# c="vomiting" 66:4 66:4||t="problem"||a="absent"
# ['a="absent"']
# c="swelling" 124:14 124:14||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="edema" 97:12 97:12||t="problem"||a="absent"
# ['a="absent"']
# c="weakness" 64:4 64:4||t="problem"||a="absent"
# ['a="absent"']
# c="thad lesion" 107:0 107:1||t="problem"||a="present"
# ['a="present"']
# c="a facet hypertrophy" 107:5 107:7||t="problem"||a="present"
# ['a="present"']
# c="painful" 112:9 112:9||t="problem"||a="absent"
# ['a="absent"']
# c="clubbing" 97:10 97:10||t="problem"||a="absent"
# ['a="absent"']
# c="discharge" 124:17 124:17||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="your incision" 124:19 124:20||t="problem"||a="present"
# ['a="present"']
# c="diarrhea" 66:7 66:7||t="problem"||a="absent"
# ['a="absent"']
# c="dm" 53:0 53:0||t="problem"||a="present"
# ['a="present"']
# c="cyanosis" 97:8 97:8||t="problem"||a="absent"
# ['a="absent"']
# c="organomegaly" 96:11 96:11||t="problem"||a="absent"
# ['a="absent"']
# c="increased redness" 124:11 124:12||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="mildly elevated" 109:8 109:9||t="problem"||a="present"
# ['a="present"']
# c="nausea" 66:2 66:2||t="problem"||a="absent"
# ['a="absent"']
# c="carcinoma of the kidney" 16:0 16:3||t="problem"||a="present"
# ['a="present"']
# c="metastatic liver disease" 16:7 16:9||t="problem"||a="present"
# ['a="present"']
# c="hypovolemia" 16:5 16:5||t="problem"||a="present"
# ['a="present"']
# c="adynamic ileus" 33:2 33:3||t="problem"||a="present"
# ['a="present"']
# c="intrathoracic lymphadenopathy" 16:11 16:12||t="problem"||a="present"
# ['a="present"']
# c="hypovolemia" 6:5 6:5||t="problem"||a="present"
# ['a="present"']
# c="liver massively enlarged" 25:0 25:2||t="problem"||a="present"
# ['a="present"']
# c="metastatic liver" 6:7 6:8||t="problem"||a="present"
# ['a="present"']
# c="carcinoma of the kidney" 6:0 6:3||t="problem"||a="present"
# ['a="present"']
# c="masses" 22:1 22:1||t="problem"||a="absent"
# ['a="absent"']
# c="lymphadenopathy" 22:5 22:5||t="problem"||a="present"
# ['a="present"']
# c="hypotensive" 159:8 159:8||t="problem"||a="present"
# ['a="present"']
# c="trilobar pneumonia" 160:7 160:8||t="problem"||a="present"
# ['a="present"']
# c="adult respiratory distress syndrome" 160:16 160:19||t="problem"||a="present"
# ['a="present"']
# c="the multi-organ system failure syndrome" 160:21 160:25||t="problem"||a="present"
# ['a="present"']
# c="a contusion over the right eye" 53:2 53:7||t="problem"||a="present"
# ['a="present"']
# c="his profound liver failure" 158:4 158:7||t="problem"||a="present"
# ['a="present"']
# c="rising ammonias" 158:9 158:10||t="problem"||a="present"
# ['a="present"']
# c="hepatic encephalopathy" 158:12 158:13||t="problem"||a="present"
# ['a="present"']
# c="meningitis" 157:10 157:10||t="problem"||a="possible"
# ['a="possible"']
# c="sinusitis" 157:12 157:12||t="problem"||a="possible"
# ['a="possible"']
# c="positive" 91:4 91:4||t="problem"||a="present"
# ['a="present"']
# c="a seizure" 37:5 37:6||t="problem"||a="present"
# ['a="present"']
# c="a prolonged qt" 92:9 92:11||t="problem"||a="present"
# ['a="present"']
# c="trauma" 56:15 56:15||t="problem"||a="present"
# ['a="present"']
# c="minimally reactive" 56:26 56:27||t="problem"||a="present"
# ['a="present"']
# c="erythema" 56:36 56:36||t="problem"||a="absent"
# ['a="absent"']
# c="anicteric" 56:39 56:39||t="problem"||a="absent"
# ['a="absent"']
# c="shotty cervical adenopathy" 55:2 55:4||t="problem"||a="present"
# ['a="present"']
# c="coagulase negative staphylococcus" 149:4 149:6||t="problem"||a="present"
# ['a="present"']
# c="his profound hypertension" 149:15 149:17||t="problem"||a="present"
# ['a="present"']
# c="mild percussion tenderness" 68:14 68:16||t="problem"||a="present"
# ['a="present"']
# c="flank discoloration" 53:19 53:20||t="problem"||a="absent"
# ['a="absent"']
# c="bruits" 67:8 67:8||t="problem"||a="absent"
# ['a="absent"']
# c="superficial tenderness" 69:8 69:9||t="problem"||a="possible"
# ['a="possible"']
# c="volume requirements" 147:11 147:12||t="problem"||a="present"
# ['a="present"']
# c="abrasion of her left shoulder" 53:12 53:16||t="problem"||a="present"
# ['a="present"']
# c="laceration" 53:10 53:10||t="problem"||a="absent"
# ['a="absent"']
# c="8-pancreatitis" 145:0 145:0||t="problem"||a="present"
# ...
# ['a="present"']
# c="dry gangrene" 36:4 36:5||t="problem"||a="present"
# ['a="present"']
# c="cad" 28:0 28:0||t="problem"||a="present"
# ['a="present"']
# c="mild elevation" 69:3 69:4||t="problem"||a="present"
# ['a="present"']
# c="c.diff colitis" 166:1 166:2||t="problem"||a="present"
# ['a="present"']
# c="tachycardia" 19:30 19:30||t="problem"||a="present"
# ['a="present"']
# c="anemia" 169:1 169:1||t="problem"||a="present"
# ['a="present"']
# c="coronary artery disease" 168:1 168:3||t="problem"||a="present"
# ['a="present"']
# c="altered mental status" 164:1 164:3||t="problem"||a="present"
# ['a="present"']
# c="weight loss" 163:5 163:6||t="problem"||a="present"
# ['a="present"']
# c="tachycardia" 15:2 15:2||t="problem"||a="present"
# ['a="present"']
# c="gastric ulcer" 165:1 165:2||t="problem"||a="present"
# ['a="present"']
# c="territorial infarct" 42:12 42:13||t="problem"||a="absent"
# ['a="absent"']
# c="mrsa pneumonia" 162:1 162:2||t="problem"||a="present"
# ['a="present"']
# c="midline shift" 42:3 42:4||t="problem"||a="absent"
# ['a="absent"']
# c="vomiting" 180:15 180:15||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="failure to thrive" 163:1 163:3||t="problem"||a="present"
# ['a="present"']
# c="nausea" 180:13 180:13||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="hypertension" 173:1 173:1||t="problem"||a="present"
# ['a="present"']
# c="pvc 's" 67:6 67:7||t="problem"||a="present"
# ['a="present"']
# c="continued fevers" 65:6 65:7||t="problem"||a="present"
# ['a="present"']
# c="dementia" 77:4 77:4||t="problem"||a="possible"
# ['a="possible"']
# c="the patient 's cognitive symptoms" 78:3 78:7||t="problem"||a="present"
# ['a="present"']
# c="metabolic encephalopathy" 78:11 78:12||t="problem"||a="present"
# ['a="present"']
# c="his multiple medical problems" 78:15 78:18||t="problem"||a="present"
# ['a="present"']
# c="diabetes mellitus" 27:0 27:1||t="problem"||a="present"
# ['a="present"']
# c="any difficulty" 114:17 114:18||t="problem"||a="absent"
# ['a="absent"']
# c="gangrenous leg" 160:1 160:2||t="problem"||a="present"
# ['a="present"']
# c="a large gastric ulcer" 83:5 83:8||t="problem"||a="present"
# ['a="present"']
# c="urinary tract infection" 161:1 161:3||t="problem"||a="present"
# ['a="present"']
# c="tachycardia" 24:22 24:22||t="problem"||a="present"
# ['a="present"']
# c="h. pylori" 84:10 84:11||t="problem"||a="absent"
# ['a="absent"']
# c="right aka stump" 36:0 36:2||t="problem"||a="present"
# ['a="present"']
# c="urinary retention" 105:3 105:4||t="problem"||a="present"
# ['a="present"']
# c="underlying dementia" 80:0 80:1||t="problem"||a="possible"
# ['a="possible"']
# c="abdominal pain" 19:12 19:13||t="problem"||a="present"
# ['a="present"']
# c="his transplant issues" 69:16 69:18||t="problem"||a="present"
# ['a="present"']
# c="transient ischemic attack" 29:3 29:5||t="problem"||a="possible"
# ['a="possible"']
# c="peripheral edema" 65:3 65:4||t="problem"||a="absent"
# ['a="absent"']
# c="hypertension" 19:1 19:1||t="problem"||a="present"
# ['a="present"']
# c="a small umbilical hernia" 63:10 63:13||t="problem"||a="present"
# ['a="present"']
# c="nondistended" 63:7 63:7||t="problem"||a="absent"
# ['a="absent"']
# c="hypokinesis of distal anterior wall" 16:9 16:13||t="problem"||a="present"
# ['a="present"']
# c="diabetes mellitus" 21:1 21:2||t="problem"||a="present"
# ['a="present"']
# c="hypercholesterolemia" 20:1 20:1||t="problem"||a="present"
# ['a="present"']
# c="grade ii/vi systolic ejection murmur" 62:2 62:6||t="problem"||a="present"
# ['a="present"']
# c="anicteric" 58:0 58:0||t="problem"||a="absent"
# ['a="absent"']
# c="three vessel disease" 17:8 17:10||t="problem"||a="present"
# ['a="present"']
# c="noncyanotic" 64:4 64:4||t="problem"||a="absent"
# ['a="absent"']
# c="depression" 27:1 27:1||t="problem"||a="present"
# ['a="present"']
# c="nontender" 63:5 63:5||t="problem"||a="absent"
# ['a="absent"']
# c="minimal peripheral edema" 98:6 98:8||t="problem"||a="present"
# ['a="present"']
# c="a low platelet level" 81:12 81:15||t="problem"||a="present"
# ['a="present"']
# c="decreased urine output" 73:12 73:14||t="problem"||a="present"
# ['a="present"']
# c="a low hematocrit" 78:21 78:23||t="problem"||a="present"
# ['a="present"']
# c="nonedematous" 64:6 64:6||t="problem"||a="absent"
# ['a="absent"']
# c="nondistended" 97:7 97:7||t="problem"||a="absent"
# ['a="absent"']
# c="sternal click" 95:8 95:9||t="problem"||a="absent"
# ['a="absent"']
# c="lymphadenopathy" 61:5 61:5||t="problem"||a="absent"
# ['a="absent"']
# c="gout" 28:1 28:1||t="problem"||a="present"
# ['a="present"']
# c="upper gastrointestinal bleed" 26:3 26:5||t="problem"||a="present"
# ['a="present"']
# c="known drug allergies" 32:1 32:3||t="problem"||a="absent"
# ['a="absent"']
# c="chronic allograft nephropathy" 24:1 24:3||t="problem"||a="present"
# ['a="present"']
# c="a fever" 113:11 113:12||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="other significant chest pain" 113:17 113:20||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="chronic anemia" 25:1 25:2||t="problem"||a="present"
# ['a="present"']
# c="end stage renal disease" 22:1 22:4||t="problem"||a="present"
# ['a="present"']
# c="noncyanotic" 98:4 98:4||t="problem"||a="absent"
# ['a="absent"']
# c="exertional chest pressure" 15:13 15:15||t="problem"||a="conditional"
# ['a="conditional"']
# c="coronary artery disease" 10:0 10:2||t="problem"||a="present"
# ['a="present"']
# c="discharge" 95:11 95:11||t="problem"||a="absent"
# ['a="absent"']
# c="nontender" 97:5 97:5||t="problem"||a="absent"
# ['a="absent"']
# c="coronary artery disease" 12:1 12:3||t="problem"||a="present"
# ['a="present"']
# c="sternal discharge" 113:14 113:15||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="atraumatic" 55:13 55:13||t="problem"||a="absent"
# ['a="absent"']
# c="akinesis of distal inferior wall and apex" 16:15 16:21||t="problem"||a="present"
# ['a="present"']
# c="acute distress" 53:11 53:12||t="problem"||a="absent"
# ['a="absent"']
# c="congestive heart failure" 15:30 15:32||t="problem"||a="present"
# ['a="present"']
# c="her asthma" 18:9 18:10||t="problem"||a="present"
# ['a="present"']
# c="known allergy" 19:2 19:3||t="problem"||a="conditional"
# ['a="conditional"']
# c="known dilated cardiomyopathy" 16:2 16:4||t="problem"||a="present"
# ['a="present"']
# c="any acute cardiac decompensation" 35:8 35:11||t="problem"||a="possible"
# ['a="possible"']
# c="shortness of breath" 39:25 39:27||t="problem"||a="present"
# ['a="present"']
# c="fluid shifts" 39:29 39:30||t="problem"||a="present"
# ['a="present"']
# c="increasing shortness of breath" 39:8 39:11||t="problem"||a="present"
# ['a="present"']
# c="atrioseptal defect" 13:3 13:4||t="problem"||a="present"
# ['a="present"']
# c="congestive heart failure" 8:1 8:3||t="problem"||a="present"
# ['a="present"']
# c="intrauterine pregnancy" 10:4 10:5||t="problem"||a="present"
# ['a="present"']
# c="dilated cardiomyopathy" 9:1 9:2||t="problem"||a="present"
# ['a="present"']
# c="congestive heart failure" 29:2 29:4||t="problem"||a="present"
# ['a="present"']
# c="the decompensation" 32:21 32:22||t="problem"||a="present"
# ['a="present"']
# c="chronic hypertension" 11:1 11:2||t="problem"||a="present"
# ['a="present"']
# c="bilateral lower extremity edema" 24:9 24:12||t="problem"||a="present"
# ['a="present"']
# c="jugular venous distension" 24:25 24:27||t="problem"||a="present"
# ['a="present"']
# c="mildly elevated pressures" 24:14 24:16||t="problem"||a="present"
# ['a="present"']
# c="asthma" 12:1 12:1||t="problem"||a="present"
# ['a="present"']
# c="congestive heart failure" 21:7 21:9||t="problem"||a="present"
# ['a="present"']
# c="decreased fetal movement" 21:13 21:15||t="problem"||a="present"
# ['a="present"']
# c="complication" 46:12 46:12||t="problem"||a="absent"
# ['a="absent"']
# c="seasonal allergies" 21:1 21:2||t="problem"||a="present"
# ['a="present"']
# c="diabetes" 19:1 19:1||t="problem"||a="present"
# ['a="present"']
# c="disorientation" 53:16 53:16||t="problem"||a="absent"
# ['a="absent"']
# c="critical aortic stenosis" 16:20 16:22||t="problem"||a="present"
# ['a="present"']
# c="his incisions" 75:5 75:6||t="problem"||a="present"
# ['a="present"']
# c="arthritis" 22:1 22:1||t="problem"||a="present"
# ['a="present"']
# c="afebrile" 54:12 54:12||t="problem"||a="absent"
# ['a="absent"']
# c="shortness of breath" 14:9 14:11||t="problem"||a="conditional"
# ['a="conditional"']
# c="hypertension" 20:1 20:1||t="problem"||a="present"
# ['a="present"']
# c="cellulitis" 55:16 55:16||t="problem"||a="absent"
# ['a="absent"']
# c="hemodynamically significant coronary artery disease" 16:13 16:17||t="problem"||a="absent"
# ['a="absent"']
# c="purulent drainage" 55:18 55:19||t="problem"||a="absent"
# ['a="absent"']
# c="complication" 51:14 51:14||t="problem"||a="absent"
# ['a="absent"']
# c="this condition" 12:25 12:26||t="problem"||a="present"
# ['a="present"']
# c="critical aortic stenosis" 12:8 12:10||t="problem"||a="present"
# ['a="present"']
# c="complication" 45:14 45:14||t="problem"||a="absent"
# ['a="absent"']
# c="dizziness" 14:7 14:7||t="problem"||a="conditional"
# ['a="conditional"']
# c="dyspnea" 13:9 13:9||t="problem"||a="conditional"
# ['a="conditional"']
# c="increasing fatigue" 13:6 13:7||t="problem"||a="present"
# ['a="present"']
# c="critical fibrocalcific aortic stenosis" 15:9 15:12||t="problem"||a="present"
# ['a="present"']
# c="1+ aortic and mitral insufficiency" 15:35 15:39||t="problem"||a="present"
# ['a="present"']
# c="confusion" 53:18 53:18||t="problem"||a="absent"
# ['a="absent"']
# c="complication" 47:14 47:14||t="problem"||a="absent"
# ['a="absent"']
# c="coughing spells" 14:14 14:15||t="problem"||a="conditional"
# ['a="conditional"']
# c="his incision" 55:0 55:1||t="problem"||a="present"
# ['a="present"']
# c="incisions" 76:8 76:8||t="problem"||a="present"
# ['a="present"']
# c="allergic" 32:3 32:3||t="problem"||a="conditional"
# ['a="conditional"']
# c="his pain" 57:11 57:12||t="problem"||a="present"
# ['a="present"']
# c="cad/chf" 111:1 111:1||t="problem"||a="present"
# ['a="present"']
# c="his acute gi bleed" 111:20 111:23||t="problem"||a="present"
# ['a="present"']
# c="m/r/g" 55:7 55:7||t="problem"||a="absent"
# ['a="absent"']
# c="lower abdominal pain" 99:16 99:18||t="problem"||a="present"
# ['a="present"']
# c="anicteric sclera" 53:2 53:3||t="problem"||a="absent"
# ['a="absent"']
# c="nad" 52:6 52:6||t="problem"||a="absent"
# ['a="absent"']
# c="a pe" 118:19 118:20||t="problem"||a="present"
# ['a="present"']
# c="recurrent dvts" 118:15 118:16||t="problem"||a="present"
# ['a="present"']
# c="pe" 39:9 39:9||t="problem"||a="present"
# ['a="present"']
# c="mucosal signs" 108:12 108:13||t="problem"||a="present"
# ['a="present"']
# c="moderate ulcerative colitis" 108:15 108:17||t="problem"||a="present"
# ['a="present"']
# c="8 mm ulcer at junction of distal descending colon and sigmoid colon" 108:23 108:34||t="problem"||a="present"
# ['a="present"']
# c="polyps" 108:20 108:20||t="problem"||a="absent"
# ['a="absent"']
# c="cp" 30:2 30:2||t="problem"||a="absent"
# ['a="absent"']
# c="bleeding vessel" 18:6 18:7||t="problem"||a="present"
# ['a="present"']
# c="jvd" 54:2 54:2||t="problem"||a="absent"
# ['a="absent"']
# c="a symptom" 23:13 23:14||t="problem"||a="present"
# ['a="present"']
# c="nt" 57:7 57:7||t="problem"||a="absent"
# ['a="absent"']
# c="sinus node dysfunction" 38:1 38:3||t="problem"||a="present"
# ['a="present"']
# c="chf" 35:1 35:1||t="problem"||a="present"
# ['a="present"']
# c="ulcerative colitis" 40:1 40:2||t="problem"||a="present"
# ['a="present"']
# c="significant unexplained weight loss" 163:30 163:33||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="minimally distended" 57:4 57:5||t="problem"||a="present"
# ['a="present"']
# c="dm" 149:20 149:20||t="problem"||a="present"
# ['a="present"']
# c="rectal bleeding from inferior mesenteric artery tributaries" 160:0 160:6||t="problem"||a="present"
# ['a="present"']
# c="left adrenal fat-containing lesion" 92:4 92:7||t="problem"||a="present"
# ['a="present"']
# c="a myelolipoma" 92:10 92:11||t="problem"||a="possible"
# ['a="possible"']
# c="ulcerative colitis" 150:35 150:36||t="problem"||a="present"
# ['a="present"']
# c="severe flares" 150:39 150:40||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="active source of bleeding" 104:22 104:25||t="problem"||a="absent"
# ['a="absent"']
# c="his risk of bleeding" 113:0 113:3||t="problem"||a="present"
# ['a="present"']
# c="cyanosis" 58:8 58:8||t="problem"||a="absent"
# ['a="absent"']
# c="sudden blurry vision" 163:17 163:19||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="rales" 56:4 56:4||t="problem"||a="absent"
# ['a="absent"']
# c="bleeding in two vessels" 101:3 101:6||t="problem"||a="present"
# ['a="present"']
# c="the patient 's bright red blood per rectum" 91:12 91:19||t="problem"||a="present"
# ['a="present"']
# c="ulcerative colitis" 110:1 110:2||t="problem"||a="present"
# ['a="present"']
# c="brbpr" 22:27 22:27||t="problem"||a="present"
# ['a="present"']
# c="subcentimeter attenuation lesion within the lower pole" 94:1 94:7||t="problem"||a="present"
# ['a="present"']
# c="dvt" 39:2 39:2||t="problem"||a="present"
# ['a="present"']
# c="cad" 34:1 34:1||t="problem"||a="present"
# ['a="present"']
# c="rebound/guarding" 57:10 57:10||t="problem"||a="absent"
# ['a="absent"']
# c="3-mm noncalcified pulmonary nodule within the right lower lobe" 95:1 95:9||t="problem"||a="present"
# ['a="present"']
# c="lbbb" 37:1 37:1||t="problem"||a="present"
# ['a="present"']
# c="slurred speech" 163:21 163:22||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="dm-2" 114:1 114:1||t="problem"||a="present"
# ['a="present"']
# c="hypovolemic" 25:39 25:39||t="problem"||a="possible"
# ['a="possible"']
# c="shortness of breath" 163:6 163:8||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="dm-2" 33:1 33:1||t="problem"||a="present"
# ['a="present"']
# c="brpbr" 99:23 99:23||t="problem"||a="present"
# ['a="present"']
# c="a large , bloody bowel movement" 27:11 27:16||t="problem"||a="present"
# ['a="present"']
# c="a uti" 24:7 24:8||t="problem"||a="present"
# ['a="present"']
# c="chest pain" 163:24 163:25||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="clot" 27:6 27:6||t="problem"||a="present"
# ['a="present"']
# c="bleeding" 119:8 119:8||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="hypodense lesion within the caudate lobe" 93:4 93:9||t="problem"||a="present"
# ['a="present"']
# c="uc" 99:10 99:10||t="problem"||a="present"
# ['a="present"']
# c="sob" 30:4 30:4||t="problem"||a="absent"
# ['a="absent"']
# c="dm2" 22:9 22:9||t="problem"||a="present"
# ['a="present"']
# c="right parietal intracranial bleeding" 36:1 36:4||t="problem"||a="present"
# ['a="present"']
# c="ulcerative colitis" 22:21 22:22||t="problem"||a="present"
# ['a="present"']
# c="cad" 22:11 22:11||t="problem"||a="present"
# ['a="present"']
# c="increased tracer activity" 87:2 87:4||t="problem"||a="present"
# ['a="present"']
# c="active bleeding" 87:22 87:23||t="problem"||a="possible"
# ['a="possible"']
# c="trace edema at ankles" 58:2 58:5||t="problem"||a="present"
# ['a="present"']
# c="bleeding" 105:16 105:16||t="problem"||a="possible"
# ['a="possible"']
# c="old blood in the rectal vault" 104:14 104:19||t="problem"||a="present"
# ['a="present"']
# c="dvt/pe" 22:15 22:15||t="problem"||a="present"
# ['a="present"']
# c="dvt/pe" 115:2 115:2||t="problem"||a="present"
# ['a="present"']
# c="a primary malignancy" 96:9 96:11||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="his acute bleed" 103:8 103:10||t="problem"||a="present"
# ['a="present"']
# c="faintness" 163:27 163:27||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="hemoconcentrated" 25:42 25:42||t="problem"||a="present"
# ['a="present"']
# c="a large , bloody bowel movement" 25:8 25:13||t="problem"||a="present"
# ['a="present"']
# c="other bowel pathology" 91:6 91:8||t="problem"||a="absent"
# ['a="absent"']
# c="chf" 99:8 99:8||t="problem"||a="present"
# ['a="present"']
# c="lower abdominal pain" 23:4 23:6||t="problem"||a="present"
# ['a="present"']
# c="continued brbpr" 30:9 30:10||t="problem"||a="absent"
# ['a="absent"']
# c="his lower gi bleed" 100:12 100:15||t="problem"||a="present"
# ['a="present"']
# c="abd pain" 30:6 30:7||t="problem"||a="absent"
# ['a="absent"']
# c="cad" 99:6 99:6||t="problem"||a="present"
# ['a="present"']
# c="colitis" 91:4 91:4||t="problem"||a="absent"
# ['a="absent"']
# c="weakness in your legs or arms" 163:10 163:15||t="problem"||a="hypothetical"
# ['a="hypothetical"']
# c="dm2" 99:4 99:4||t="problem"||a="present"
# ['a="present"']
# c="brbpr" 100:1 100:1||t="problem"||a="present"
# ['a="present"']

# %%
print(records_dict['record-21']['words'][100:120])
print(records_dict['record-21']['tags'][100:120])
# Out:
# ['be', 'awake', ',', 'but', 'confused', 'at', 'the', 'scene', 'of', 'the', 'accident', 'with', 'no', 'memory', 'of', 'the', 'incident', '.', 'She', 'was']
# ['O', 'O', 'O', 'O', 'present', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
df = pd.DataFrame(records_dict)
df_trans = df.transpose()
df_trans.head(3)
# Out:
#                                                        words  \
# record-20  [Admission, Date, :, 2013-06-12, Discharge, Da...
# record-21  [01909607, Admission, Date, :, 2010-06-28, Dis...
# record-22  [Admission, Date, :, 2018-10-25, Discharge, Da...
#
#                                                         tags
# record-20  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# record-21  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# record-22  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1

# %%
X = df_trans['words']
y = df_trans['tags']

tags = []

for row in y:
  for r in row:
    if r not in tags:
      tags.append(r)

# %%
info_dict = {}
info_dict['id'] = list(map(str,list(df_trans.index)))
info_dict['tokens'] = list(X.values)
info_dict['ner_tags'] = list(y.values)

from datasets import Dataset, Sequence, ClassLabel

dataset = Dataset.from_dict(info_dict)
dataset = dataset.cast_column('ner_tags', Sequence(ClassLabel(names=tags)))
dataset
# Out:
# Casting the dataset:   0%|          | 0/426 [00:00<?, ? examples/s]
# Dataset({
#     features: ['id', 'tokens', 'ner_tags'],
#     num_rows: 426
# })

# %%
PATH = './drive/MyDrive/model_biobert_20240406'
tokenizer = AutoTokenizer.from_pretrained(PATH, local_files_only=True)
from transformers import AutoModelForTokenClassification
model = AutoModelForTokenClassification.from_pretrained(PATH, local_files_only=True)

# %%
tokenized_input = tokenizer(records_dict['record-21']['words'], is_split_into_words=True)
tokens = tokenizer.convert_ids_to_tokens(tokenized_input["input_ids"])
word_ids = tokenized_input.word_ids()
aligned_labels = [-100 if i is None else records_dict['record-21']['tags'][i] for i in word_ids]

assert len(aligned_labels) == len(tokenized_input["input_ids"])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2055 > 512). Running this sequence through the model will result in indexing errors

# %%
tokenized_input = tokenizer(records_dict['record-21']['words'], is_split_into_words=True)
tokens = tokenizer.convert_ids_to_tokens(tokenized_input["input_ids"])
word_ids = tokenized_input.word_ids()
aligned_labels = [-100 if i is None else records_dict['record-21']['tags'][i] for i in word_ids]
print(tokenized_input["input_ids"])
print(aligned_labels)
# Out:
# [101, 5187, 21500, 1580, 16480, 1559, 24930, 11234, 14265, 131, 1333, 118, 5037, 118, 1743, 14856, 7111, 2176, 14265, 131, 1333, 118, 5004, 118, 5187, 14265, 1104, 20729, 131, 1997, 118, 5507, 118, 5187, 9850, 131, 143, 2516, 131, 23066, 24162, 17195, 10069, 9741, 145, 6258, 18082, 2069, 3663, 11345, 7462, 11629, 9919, 11680, 1942, 15393, 2162, 22680, 12480, 131, 1188, 1110, 170, 1406, 118, 1214, 118, 1385, 2130, 1114, 1185, 2418, 1763, 2657, 1607, 117, 1150, 1108, 1103, 18366, 11098, 1174, 4059, 1107, 170, 1344, 2420, 5155, 5909, 5968, 3686, 4216, 1113, 1333, 118, 5037, 118, 1765, 119, 1650, 2592, 117, 1103, 5351, 1108, 25292, 1121, 1103, 3686, 1113, 3772, 1105, 1276, 7787, 1107, 1103, 175, 21470, 1700, 1120, 1103, 3876, 1104, 1103, 3686, 1120, 1103, 2741, 119, 1109, 3686, 1108, 2382, 1106, 1129, 7620, 4938, 119, 1650, 2592, 117, 1103, 5351, 1108, 2382, 1106, 1129, 8264, 117, 1133, 4853, 1120, 1103, 2741, 1104, 1103, 4216, 1114, 1185, 2962, 1104, 1103, 4497, 119, 1153, 1108, 13280, 3702, 15197, 2200, 1107, 1103, 140, 118, 8340, 9704, 1120, 1103, 2741, 1104, 1103, 4216, 1105, 2886, 9470, 1118, 142, 7182, 1106, 1103, 1203, 1652, 22986, 3355, 111, 11336, 17266, 1945, 11177, 1951, 1111, 1748, 2635, 119, 153, 3048, 3663, 13882, 11356, 2162, 142, 3190, 10964, 11607, 13821, 24805, 131, 26947, 1113, 8685, 1106, 1103, 5241, 1395, 3090, 1103, 1378, 131, 12008, 20900, 17337, 2588, 119, 125, 24664, 3447, 3285, 117, 1892, 2997, 13096, 120, 5519, 117, 8561, 8359, 117, 19192, 2603, 1407, 117, 7621, 2068, 23022, 5103, 110, 1113, 1395, 1586, 119, 1109, 5351, 1108, 10427, 1105, 7779, 1551, 1210, 1107, 1185, 6281, 13632, 119, 2859, 3291, 1918, 20334, 1104, 1405, 119, 5331, 8223, 7192, 1665, 10936, 1116, 1127, 2382, 1106, 1129, 2330, 119, 153, 4455, 8825, 1127, 4463, 117, 1668, 117, 26844, 1106, 1609, 1120, 2324, 125, 2608, 119, 1109, 5351, 112, 188, 189, 19366, 13836, 1108, 2382, 1106, 1129, 2286, 2568, 119, 1109, 5351, 112, 188, 13093, 8179, 3090, 1103, 8682, 1106, 1129, 2330, 1106, 12686, 1116, 10182, 23934, 2116, 20557, 1193, 117, 1185, 172, 1874, 18965, 1361, 117, 1105, 170, 1286, 172, 9516, 20899, 19353, 24211, 1785, 1108, 10272, 1193, 6281, 1113, 8179, 119, 8784, 23354, 9984, 1658, 131, 10103, 12571, 8179, 7160, 2366, 2603, 1105, 6795, 117, 1185, 26792, 117, 16259, 1116, 117, 1137, 20003, 22101, 119, 16151, 2137, 13041, 11680, 131, 19539, 117, 1664, 22910, 1200, 117, 1664, 10396, 21857, 119, 155, 8231, 9159, 2162, 131, 26947, 1108, 176, 6718, 12571, 4366, 1114, 1363, 1231, 5822, 1348, 3586, 119, 1109, 5351, 112, 188, 185, 1883, 9356, 1108, 6111, 1106, 10997, 1105, 11937, 14928, 119, 138, 126, 3975, 15170, 6108, 1108, 2382, 1166, 1103, 5351, 112, 188, 184, 19557, 16156, 1113, 1748, 11820, 1114, 1185, 5490, 10311, 6028, 119, 4114, 3105, 4252, 7877, 15455, 8179, 7160, 9964, 5968, 117, 19144, 117, 1105, 26557, 3053, 119, 8123, 3105, 4252, 7877, 15455, 8179, 7160, 1185, 10272, 19353, 24211, 4233, 117, 8886, 1757, 1106, 185, 1348, 22578, 1107, 1103, 2286, 17284, 117, 9964, 5968, 3053, 1107, 1103, 3151, 117, 17172, 117, 1105, 23449, 13380, 9071, 23190, 117, 9964, 8710, 1106, 1609, 2828, 1107, 1103, 3151, 1105, 17172, 9071, 23190, 117, 10558, 8710, 1107, 1103, 23449, 13380, 118, 9071, 3735, 117, 3258, 1105, 1218, 1679, 21089, 16864, 1114, 123, 116, 17172, 27631, 119, 4114, 2211, 4252, 7877, 15455, 8179, 7160, 10496, 20085, 1105, 174, 19515, 7889, 11828, 1548, 1104, 1103, 1268, 16530, 9973, 1105, 2324, 170, 124, 3975, 15170, 6108, 1107, 1103, 2211, 3420, 117, 26005, 1104, 8828, 7919, 1104, 2530, 188, 2083, 4759, 4633, 119, 1302, 10272, 19353, 24211, 4233, 119, 8226, 117, 19144, 117, 1105, 26557, 17865, 1127, 9964, 1107, 1155, 23190, 119, 8123, 2211, 4252, 7877, 15455, 8179, 7160, 1185, 10272, 19353, 24211, 4233, 1105, 9964, 5968, 117, 19144, 117, 1105, 26557, 17865, 1107, 1155, 23190, 119, 2664, 11293, 2527, 7160, 1126, 15543, 13577, 1286, 2286, 1665, 9516, 20899, 22869, 117, 1185, 2554, 1104, 185, 1673, 1818, 12858, 25632, 119, 157, 1611, 10161,  ...
# [-100, 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'present', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'absent', 'O', 'O', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'O', 'absent', 'absent', 'O', 'O', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'O', 'absent', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'present', 'present', 'present', 'present', 'present', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'absent', 'O', 'present', 'present', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'present', 'present', 'O', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'O', 'O', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'present', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'absent', 'absent', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'absent', 'absent', 'absent', 'absent', 'absent', 'ab ...

# %%
for i,label in enumerate(aligned_labels):
  if i == 20:
    break
  print(tokens[i],':',label)
# Out:
# [CLS] : -100
# 01 : O
# ##90 : O
# ##9 : O
# ##60 : O
# ##7 : O
# Ad : O
# ##mission : O
# Date : O
# : : O
# 2010 : O
# - : O
# 06 : O
# - : O
# 28 : O
# Disc : O
# ##har : O
# ##ge : O
# Date : O
# : : O

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True, max_length=512,
                                stride=3, return_overflowing_tokens=True
                                 )

    sample_map = tokenized_inputs.pop("overflow_to_sample_mapping")
    for key, values in examples.items():
        tokenized_inputs[key] = [values[i] for i in sample_map]

    labels = []
    for i, label in enumerate(tokenized_inputs["ner_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)

        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            # Special tokens have a word id that is None. We set the label to -100 so they are automatically
            # ignored in the loss function.
            if word_idx is None:
                label_ids.append(-100)
            # We set the label for the first token of each word.
            elif word_idx != previous_word_idx:
                label_ids.append(label[word_idx])
            # For the other tokens in a word, we set the label to either the current label or -100, depending on
            # the label_all_tokens flag.
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx

        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_datasets = dataset.map(tokenize_and_align_labels,batched=True)
# Out:
# Map:   0%|          | 0/426 [00:00<?, ? examples/s]

# %%
words = tokenized_datasets[20]['tokens']
labels = tokenized_datasets[20]['ner_tags']

ner_feature = tokenized_datasets.features["ner_tags"]
label_names = ner_feature.feature.names

line1 = ""
line2 = ""
for word, label in zip(words, labels):
    full_label = label_names[label]
    max_length = max(len(word), len(full_label))
    line1 += word + " " * (max_length - len(word) + 1)
    line2 += full_label + " " * (max_length - len(full_label) + 1)

print(line1)
print(line2)
# Out:
# Admission Date : 2016-12-30 Discharge Date : 2017-01-13 Date of Birth : 1960-09-05 Sex : M Service : HISTORY OF PRESENT ILLNESS : This is a 56 year old man with history of hypercholesterolemia and type    II      diabetes mellitus . He has a recent history of dyspnea     on exertion on exertional chest   pain    which has increased over the last several weeks and is relieved by sublingual nitroglycerin . On 2016-06-26 , he had a       positive exercise tolerance test    . Cardiac catheterization at the end of October revealed a       dilated aortic  root    to 4.4 cm and 80%     stenosis of      the     mid     left    anterior descending at the bifurcation involving the diagonal branch , 70%     stenoses of      the     left    circumflex and     oblique marginal artery  and 90%     stenosis of      the     posterior descending artery  . His atrioventricular valve gradient was 27 with an AV surface area of .91 . REVIEW OF SYSTEMS : Review of systems shows that the patient denies any    orthopnea , paroxysmal nocturnal dyspnea . He has no bleeding or clotting problems . Juanita does not feel any    palpitations . He does not have wheezing , claudication or gastrointestinal bleeding . Nor does he have any history of stroke like   symptoms . PAST MEDICAL HISTORY : Hypercholesterolemia . Type    II      diabetes . Recent  pneumonia . Remote tobacco use . Recent  weight  loss    associated with the     pneumonia . Gastroesophageal reflux  disease . ALLERGIES : No known  drug   allergies . MEDICATIONS ON ADMISSION : One aspirin a day . Nexium 40 mg a day . Carvedilol 6.125 mg a day . Glucophage 25 mg once a day . Lipitor 10 mg once a day . SOCIAL HISTORY : He lives with his wife and works as a drug representative for Carvedilol . PHYSICAL EXAMINATION : On physical examination , the patient is afebrile . Weight is 82 kilograms . Blood pressure 126/66 . General : Active , well-developed , well-nourished male . Head and neck examination : No bruits appreciated . Lungs are clear to auscultation bilaterally . Heart was regular rate and rhythm . S1 and S2 . 3/6     systolic ejection murmur  throughout his precordium . His abdomen is soft , nontender , nondistended . No hepatosplenomegaly and no CVA    tenderness . Extremities are warm , well perfused , no cyanosis , clubbing or edema  . Palpable dorsalis pedis pulses . No varicosities noted . The patient was also noted to be right handed . HOSPITAL COURSE : He was admitted to the cardiac surgery service for an elected Bental procedure with homograft and coronary artery bypass graft . Once consent and preoperative evaluation was complete , he was taken to the operating room . Please refer to the previously dictated operative note of 2016-12-30 by Dr. Lawrence . Briefly , the patient was taken to the operating room to repair his     critical aortic  stenosis , his     coronary artery  disease and his     significantly dilated ascending aortic  aneurysm . The procedure was an aortic valve replacement with a tissue valve , a coronary artery bypass graft procedure where five grafts were performed . The left internal mammary artery was connected to the proximal left anterior descending and saphenous vein grafts were connected to the posterior descending artery , diagonal branch , obtuse marginal and distal left anterior descending . Finally , a super coronary arch graft was implanted . This was a .................... graft . Cardiopulmonary bypass time was 234 minutes . His aorta was cross clamped for 168 minutes . He had pharmacologic circulatory arrest for 18 minutes . The patient tolerated the procedure well and was transferred to the unit , intubated on Milrinone , Levophed and Propofol drips . The rest of the hospital stay can be discussed in terms of system based approach . Pulmonary : The patient remained intubated until postoperative day number five . After that , the patient had no major  problems with   his    lungs  . His oxygen saturations remained good and he did not require suppl ...
# O         O    O O          O         O    O O          O    O  O     O O          O   O O O       O O       O  O       O       O O    O  O O  O    O   O   O    O       O  present              O   present present present  present  O O  O   O O      O       O  conditional O  O        O  present    present present O     O   O         O    O   O    O       O     O   O  O        O  O          O             O O  O          O O  O   present present  present  present   present O O       O               O  O   O   O  O       O        present present present present O  O   O  O   present present  present present present present present  present    O  O   O           O         O   O        O      O present present  present present present present    present present present  present O   present present  present present present   present    present O O   O                O     O        O   O  O    O  O  O       O    O  O   O O      O  O       O O      O  O       O     O    O   O       O      absent absent    O absent     absent    absent  O O  O   O  absent   O  absent   absent   O O       O    O   O    absent absent       O O  O    O   O    absent   O absent       O  absent           absent   O O   O    O  O    O   O       O  absent absent absent   O O    O       O       O present              O present present present  O present present   O O      O       O   O present present present O          O    present present   O present          present present O O         O O  absent absent absent    O O           O  O         O O   O       O O   O O      O  O  O O   O O          O     O  O O   O O          O  O  O    O O   O O       O  O  O    O O   O O      O       O O  O     O    O   O    O   O     O  O O    O              O   O          O O        O           O O  O        O           O O   O       O  absent   O O      O  O  O         O O     O        O      O O       O O      O O              O O              O    O O    O   O    O           O O  absent O           O O     O   O     O  O            O           O O     O   O       O    O   O      O O  O   O  O present present  present  present O          O   O          O O   O       O  O    O absent    O absent       O O  absent             O   O  absent absent     O O           O   O    O O    O        O O  absent   O absent   O  absent O O        O        O     O      O O  absent       O     O O   O       O   O    O     O  O  O     O      O O        O      O O  O   O        O  O   O       O       O       O   O  O       O      O         O    O         O   O        O      O      O     O O    O       O   O            O          O   O        O O  O   O     O  O   O         O    O O      O     O  O   O          O        O         O    O  O          O  O   O        O O       O O   O       O   O     O  O   O         O    O  O      present present  present present  O present present  present present O   present present       present present   present present  O O   O         O   O  O      O     O           O    O O      O     O O O        O      O      O     O         O     O    O      O    O         O O   O    O        O       O      O   O         O  O   O        O    O        O          O   O         O    O      O    O         O  O   O         O          O      O O        O      O O      O        O   O      O    O        O          O O       O O O     O        O    O     O   O         O O    O   O O                    O     O O               O      O    O   O   O       O O   O     O   O     O       O   O   O       O O  O   O             O           O      O   O  O       O O   O       O         O   O         O    O   O   O           O  O   O    O O         O  O         O O        O   O        O     O O   O    O  O   O        O    O   O  O         O  O     O  O      O     O        O O         O O   O       O        O         O     O             O   O      O    O O     O    O O   O       O   O  absent absent   absent absent absent O O   O      O           O        O    O   O  O   O   O       O     ...

# %%
my_dataset = tokenized_datasets.train_test_split(test_size=0.2,seed=42)

# %%
my_dataset2 = my_dataset['test'].train_test_split(test_size=0.5,seed=42)

# %%
my_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 1227
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 307
#     })
# })

# %%
from datasets import DatasetDict
final_dataset = DatasetDict({
    'train': my_dataset['train'],
    'validation':my_dataset2['train'],
    'test':my_dataset2['test']
})

# %%
final_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 1227
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 153
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 154
#     })
# })

# %%
ner_feature = final_dataset["train"].features["ner_tags"]

# %%
label_names = ner_feature.feature.names

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer,return_tensors='pt')

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.13.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Installing collected packages: responses, evaluate
# Successfully installed evaluate-0.4.1 responses-0.18.0

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 950.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.4.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=245aece4dca8e7bccb71a263e84158daa2cd2196efc4a439373be3c8ce276f4a
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
import evaluate

metric = evaluate.load('seqeval')
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
labels = final_dataset["train"][0]["ner_tags"]
labels = [label_names[i] for i in labels]

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer

def compute_metrics(eval_preds):
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)

    # Remove ignored index (special tokens) and convert to labels
    true_labels = [[label_names[l] for l in label if l != -100] for label in labels]
    true_predictions = [
        [label_names[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    #cr = classification_report(MultiLabelBinarizer().fit_transform(true_labels),MultiLabelBinarizer().fit_transform(true_predictions))
    all_metrics = metric.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": all_metrics["overall_precision"],
        "recall": all_metrics["overall_recall"],
        "f1": all_metrics["overall_f1"],
        "accuracy": all_metrics["overall_accuracy"]
    }

# %%
id2label = {i: label for i, label in enumerate(label_names)}
label2id = {v: k for k, v in id2label.items()}

# %%
print(id2label)
print(label2id)
# Out:
# {0: 'O', 1: 'absent', 2: 'present', 3: 'hypothetical', 4: 'possible', 5: 'conditional', 6: 'associated_with_someone_else'}
# {'O': 0, 'absent': 1, 'present': 2, 'hypothetical': 3, 'possible': 4, 'conditional': 5, 'associated_with_someone_else': 6}

# %%
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.39.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.2.1+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.29.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)

# %%
# !pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
# hyperparameters: optimizer, weight_decay, learning_rate, batch_size
from transformers import TrainingArguments
from transformers import EarlyStoppingCallback, IntervalStrategy

args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy=IntervalStrategy.STEPS,
    eval_steps = 50,
    save_total_limit = 5,
    learning_rate=2e-5,
    num_train_epochs=20,
    weight_decay=0.01,
    logging_steps=1,
    metric_for_best_model = 'f1',
    load_best_model_at_end=True,
    seed = 42
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=final_dataset["train"],
    eval_dataset=final_dataset["validation"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
    callbacks = [EarlyStoppingCallback(early_stopping_patience=2)]
)
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#     <div>
#
#       <progress value='750' max='3080' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 750/3080 12:50 < 40:00, 0.97 it/s, Epoch 4/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.135700</td>
#       <td>0.148859</td>
#       <td>0.640755</td>
#       <td>0.702794</td>
#       <td>0.670342</td>
#       <td>0.960747</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.051700</td>
#       <td>0.115014</td>
#       <td>0.717006</td>
#       <td>0.779865</td>
#       <td>0.747116</td>
#       <td>0.969525</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.031500</td>
#       <td>0.106081</td>
#       <td>0.764651</td>
#       <td>0.791908</td>
#       <td>0.778041</td>
#       <td>0.972672</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.041600</td>
#       <td>0.109713</td>
#       <td>0.773463</td>
#       <td>0.805877</td>
#       <td>0.789337</td>
#       <td>0.973453</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.055600</td>
#       <td>0.105727</td>
#       <td>0.778552</td>
#       <td>0.807803</td>
#       <td>0.792908</td>
#       <td>0.974257</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.044700</td>
#       <td>0.102903</td>
#       <td>0.782446</td>
#       <td>0.807322</td>
#       <td>0.794689</td>
#       <td>0.974423</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.015200</td>
#       <td>0.108199</td>
#       <td>0.782810</td>
#       <td>0.815992</td>
#       <td>0.799057</td>
#       <td>0.974636</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.041400</td>
#       <td>0.111349</td>
#       <td>0.793785</td>
#       <td>0.812139</td>
#       <td>0.802857</td>
#       <td>0.975062</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.023500</td>
#       <td>0.104613</td>
#       <td>0.805998</td>
#       <td>0.828516</td>
#       <td>0.817102</td>
#       <td>0.976055</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.005700</td>
#       <td>0.108361</td>
#       <td>0.810127</td>
#       <td>0.832370</td>
#       <td>0.821098</td>
#       <td>0.976907</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.012900</td>
#       <td>0.110425</td>
#       <td>0.816462</td>
#       <td>0.831407</td>
#       <td>0.823866</td>
#       <td>0.976812</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.014500</td>
#       <td>0.107041</td>
#       <td>0.796444</td>
#       <td>0.819846</td>
#       <td>0.807975</td>
#       <td>0.975795</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.002800</td>
#       <td>0.109282</td>
#       <td>0.803316</td>
#       <td>0.840077</td>
#       <td>0.821286</td>
#       <td>0.977073</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.012600</td>
#       <td>0.112787</td>
#       <td>0.804368</td>
#       <td>0.833815</td>
#       <td>0.818827</td>
#       <td>0.976481</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.013500</td>
#       <td>0.114522</td>
#       <td>0.795247</td>
#       <td>0.838150</td>
#       <td>0.816135</td>
#       <td>0.976552</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: present seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: absent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: possible seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: associated_with_someone_else seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: hypothetical seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: conditional seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# TrainOutput(global_step=750, training_loss=0.04296313763922081, metrics={'train_runtime': 774.2381, 'train_samples_per_second': 31.696, 'train_steps_per_second': 3.978, 'total_flos': 1562625240084480.0, 'train_loss': 0.04296313763922081, 'epoch': 4.87})

# %%
loss = []
learning_rate = []
epoch = []
val_loss = []
history = trainer.state.log_history
f1 = []
for step in history:
  if 'learning_rate' in step.keys() and step['step'] % 50 == 0:
    epoch.append(step['epoch'])
    learning_rate.append(step['learning_rate'])
    loss.append(step['loss'])
  elif 'eval_loss' in step.keys() and step['step'] % 50 == 0:
    val_loss.append(step['eval_loss'])
    f1.append(step['eval_f1'])
  else:
    continue

# %%
import matplotlib.pyplot as plt

plt.plot(epoch,loss,label='loss')
plt.plot(epoch,val_loss,label='val loss')
#plt.plot(epoch,list(map(lambda x: x/val_loss[0],learning_rate)),label='learning rate')
plt.plot(epoch,f1,label='F1')
plt.legend(loc='center right')
plt.title('Training History of ClinicalBERT Trained for 20 Epochs (Learning Rate Scaled for Visualization Purposes)')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
trainer.save_model('model_biobert_20240406')

# %%
# !zip -r /content/file.zip /content/model_biobert_20240406/
# Out:
#   adding: content/model_biobert_20240406/ (stored 0%)
#   adding: content/model_biobert_20240406/config.json (deflated 53%)
#   adding: content/model_biobert_20240406/training_args.bin (deflated 51%)
#   adding: content/model_biobert_20240406/tokenizer.json (deflated 70%)
#   adding: content/model_biobert_20240406/special_tokens_map.json (deflated 42%)
#   adding: content/model_biobert_20240406/vocab.txt (deflated 49%)
#   adding: content/model_biobert_20240406/model.safetensors (deflated 7%)
#   adding: content/model_biobert_20240406/tokenizer_config.json (deflated 75%)

# %%
from google.colab import files
files.download("/content/file.zip")

# %%
trainer.evaluate(final_dataset['test'])
# Out:
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:11]
#     </div>
# {'eval_loss': 0.1511160135269165,
#  'eval_precision': 0.8583674990682072,
#  'eval_recall': 0.8793432607865598,
#  'eval_f1': 0.8687287815918522,
#  'eval_accuracy': 0.9608603667136812,
#  'eval_runtime': 15.3222,
#  'eval_samples_per_second': 10.051,
#  'eval_steps_per_second': 1.305,
#  'epoch': 7.14}
